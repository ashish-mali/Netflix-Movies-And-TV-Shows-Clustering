# %% [markdown]
# <a href="https://colab.research.google.com/github/ashish-mali/Netflix-Movies-And-TV-Shows-Clustering/blob/main/Netflix_Movies_TV_Shows_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  <hr>
#
#  #  <center> <font face="Lato" color='#E50914'> ✴ Project Name
#  # <center> 📺 <font face="Times New Roman"> Netflix Movies TV Shows Clustering 📺
#
#  <hr>

# %% [markdown]
# <center><img src="https://github.com/ashish-mali/Netflix-Movies-And-TV-Shows-Clustering/blob/main/Images/project_title_netflix_title.gif?raw=true" alt="Netflix_Title_Image" width="650" height="auto"></center>

# %% [markdown]
# <hr>
#
# ##⚙ **Project Type** - Unsupervised
# ##⚙ **Contribution** - Individual
# ##⚙ **Contributor** - Ashish Mali
#
# <hr>

# %% [markdown]
# <hr>
#
# # <center> <font face="Lato" color='#E50914'>✴ Project Summary
#
# <hr>

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# <hr>
#
# # <center>![GitHub](https://img.shields.io/badge/github-%23121011.svg?style=for-the-badge&logo=github&logoColor=white)</center>
#
# # <center> <font face="Lato" color='#E50914'>✴ GitHub Link
#
# <hr>

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# <hr>
#
# # <center> <font face="Lato" color='E50914'>✴ Problem Statement
#
# <hr>

# %% [markdown]
# > The problem statement for this project is to effectively cluster the shows hosted on Netflix into distinct groups using machine learning algorithms. This is to enhance the user experience and prevent subscriber churn by providing personalized show recommendations based on user's preferences.
#
# > The aim is to group similar shows together and separate them from dissimilar shows, resulting in a model that can cluster Netflix shows into specific clusters.
#
# > The final outcome of this project will be a model that can effectively classify Netflix shows into clusters, enabling Netflix to offer personalized show suggestions to its users.

# %% [markdown]
# ## 🚦Framing The Right Questions For The Analysis
# <hr>
#
# > Framing questions is a critical step in any data analysis project because it helps to ensure that the project is focused, rigorous, and meaningful. It helps to ensure that the project team is working towards a clear set of goals and that the results of the analysis are both accurate and actionable.
#
# >1. What is the distribution of the different types of shows on Netflix (movies, TV shows, documentaries, etc.)?
# >2. Which country has the highest number of shows on Netflix, and which country produces the most content for Netflix?
# >3. What is the distribution of the release years of the shows on Netflix?
# >4. Are there any trends in the duration of the shows over time?
# Is there any correlation between the rating of a show and its duration or release year?
# >5. What are the most common genres in the listed_in column, and is there any correlation between the genres and the type of show?
#
# >6. Does the country of origin affect the rating of the shows?
# >7. Is there a significant difference in the duration of movies and TV shows on Netflix?
# >8. Does the rating of a show differ significantly between different types of shows?
# >9. Is there a correlation between the cast of a show and its popularity?
#
# >10. Which machine learning algorithm(s) would be most suitable for clustering the shows on Netflix?
# >11. What is the optimal number of clusters for the Netflix shows?
# > 12. How well does the model perform in recommending personalized shows to users?

# %% [markdown]
# <hr>
#
# # <center> <font face="Lato" color='E50914'>✴ General Guidelines
#
# <hr>

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# <hr>
#
# # <center> <font face="Lato" color='E50914'>✴ Understanding Problem Context and Business Impact
# <hr>

# %% [markdown]
# ## ▶ What is Netflix?

# %% [markdown]
# > Netflix is a subscription-based streaming service that provides users access to a vast collection of movies, TV shows, and documentaries across various genres and languages. It was founded in 1997 and has since become one of the most popular and widely-used streaming services globally, with over 200 million subscribers as of 2021.
#
# > Netflix's business model is based on a subscription-based model, where users pay a monthly fee to access its content library. The service has continued to expand its content offerings over the years, with a focus on producing and distributing original content, including TV shows, movies, and documentaries.
#
# > One of Netflix's key strategies has been to use data analytics and user behavior to personalize its content offerings for individual users, which helps to drive engagement and increase customer loyalty. Additionally, Netflix has invested heavily in technology, including its recommendation engine and streaming infrastructure, to deliver a seamless user experience.
#
# > Overall, Netflix has revolutionized the entertainment industry with its innovative approach to content delivery and personalized recommendations. Its success has inspired many other streaming services to follow suit, making it a key player in the future of the entertainment industry.
#
# <center><img src="https://github.com/ashish-mali/Netflix-Movies-And-TV-Shows-Clustering/blob/main/Images/netflix_business_model.png?raw=true" alt="Data Science Project Stages" width="800" height="400"></center>

# %% [markdown]
# ## ▶ Business Impact Analysis.

# %% [markdown]
# > <b>Improved customer satisfaction and retention rates:</b> By clustering the shows hosted on Netflix and offering personalized show recommendations to its users, Netflix can improve the user experience and prevent subscriber churn. This can lead to higher customer satisfaction and retention rates, which is crucial for the long-term success of any subscription-based business model. This can also result in positive word-of-mouth marketing and potentially attract new customers to the platform.
#
# > <b>Increased engagement and viewership:</b> By offering personalized show recommendations, Netflix can help users discover new shows that they may not have otherwise watched. This can lead to longer viewing times and potentially more subscription renewals. Additionally, if users are satisfied with the recommendations, they may be more likely to engage with the platform and spend more time watching shows, which can lead to increased revenue for Netflix.
#
# > <b>Optimized content acquisition and production:</b> Effective clustering of the shows can help Netflix in content acquisition and production. By understanding the characteristics of shows that are popular among users, the company can acquire and produce more content that is likely to be well-received. This can lead to increased viewership and revenue, as users are more likely to engage with content that they enjoy. This can also help the company save money by avoiding the acquisition or production of content that may not be popular among users.
#
# > <b>Competitive advantage:</b> Offering personalized show recommendations can give Netflix a competitive advantage over other streaming platforms. By using machine learning algorithms to cluster shows and make recommendations, Netflix can offer a more personalized experience to its users, which can attract and retain more customers. This can help the company stand out in a crowded market and potentially increase its market share.

# %% [markdown]
# <hr>
#
# # <center> <font face="Lato" color='E50914'> ✴ Project Architecture And Roadmap
#
# <hr>

# %% [markdown]
# ## <b>Key Stages In Data Science Project</b>
# <hr>

# %% [markdown]
# <center><img src="https://github.com/ashish-mali/Netflix-Movies-And-TV-Shows-Clustering/blob/main/Images/Key_stages_in_ds_project.png?raw=true" alt="Data Science Project Stages" width="800" height="350"></center>

# %% [markdown]
# > <b>Obtain</b>: In this stage, the data scientist identifies the data required to solve the problem at hand and gathers it from various sources. This can involve collecting data from databases, web scraping, API calls, or data purchases. For this project we already given the data in CSV format.
#
# > <b>Scrub</b>: In this stage, the data is cleaned, formatted, and prepared for analysis. This can involve removing missing values, dealing with outliers, handling data inconsistencies, and standardizing the format of the data. The goal is to ensure that the data is reliable and usable for analysis.
#
# > <b>Explore</b>: In this stage, the data scientist performs exploratory data analysis (EDA) to understand the characteristics of the data and identify any patterns or trends. This can involve creating visualizations, calculating summary statistics, and identifying correlations between variables.
#
# > <b>Model</b>: In this stage, the data scientist builds predictive models using the data. This can involve selecting appropriate algorithms, training and testing models, and tuning hyperparameters. The goal is to create a model that accurately predicts the target variable.
#
# > <b>Interpret</b>: In this stage, the data scientist interprets the results of the modeling process and draws conclusions from them. This can involve identifying which features are most important, evaluating the accuracy of the model, and determining whether the model can be used to make decisions in the real world. The goal is to provide insights that can be used to solve the problem at hand.

# %% [markdown]
# ## <b>Basic Framework For Machine Learning Project</b>
# <hr>

# %% [markdown]
# <center><img src="https://github.com/ashish-mali/Netflix-Movies-And-TV-Shows-Clustering/blob/main/Images/Project_Architecture.png?raw=true" alt="Data Science Project Stages" width='1280' height="720">

# %% [markdown]
# <hr>
#
# # <center> <font face="Lato" color='E50914'>✴ Let's Begin !
#
# <hr>

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Data Maipulation Libraries
import numpy as np
import pandas as pd
import datetime as dt

# Data Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# Plotly Libraries For Visualization
from collections import Counter
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode, iplot
import plotly.offline as po

# Importing missingo library which helps us to visualize the missing values
import missingno as msno

# Word Cloud library
from wordcloud import WordCloud, STOPWORDS

# For Hypothesis Testing
from scipy import stats
from statsmodels.stats.proportion import proportions_ztest

# Natrual Language Processing 
import nltk

from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

nltk.download('averaged_perceptron_tagger', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)

# libraries used to process textual data
import re
import string
string.punctuation

from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.tokenize import TweetTokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA

# Importing the contractions
import subprocess
batcmd = "pip install contractions"                                 
result = subprocess.check_output(batcmd, shell=True)
import contractions

# For Data Scaling
from sklearn.preprocessing import StandardScaler

# libraries used to implement clusters
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram

# For Cluster Assessment
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import SilhouetteVisualizer

# For Recommender System
from sklearn.metrics.pairwise import cosine_similarity

# Library of warnings would assist in ignoring warnings issued
import warnings;warnings.filterwarnings('ignore')
import warnings;warnings.simplefilter('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# Fetching the dataset url from GitHub
url = 'https://raw.githubusercontent.com/ashish-mali/Netflix-Movies-And-TV-Shows-Clustering/main/Data_Files/NETFLIX%20MOVIES%20AND%20TV%20SHOWS%20CLUSTERING.csv'

# Creating the Pandas DataFrame with the given row data
dataset = pd.read_csv(url, encoding= 'unicode_escape', index_col='show_id')

# %%
# Creating the copy of the dataset
df = dataset.copy()

# %% [markdown]
# > It is important to create the copy of the data, as further in the project we do various operations on the dataset such as Data wrangling, Data Transformation, Feature Engineering or Feature Transformation. upon doing such operations we get different dataset at the end depending on our requirement at that time so it is always a good idea to keep the orginal row data intact so we can always revert back the chnages we did in the overall process.

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# First five observations
df.head()
# Out:
#             type  title           director  \
# show_id
# s1       TV Show     3%                NaN
# s2         Movie   7:19  Jorge Michel Grau
# s3         Movie  23:59       Gilbert Chan
# s4         Movie      9        Shane Acker
# s5         Movie     21     Robert Luketic
#
#                                                       cast        country  \
# show_id
# s1       JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# s2       DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#                 date_added  release_year rating   duration  \
# show_id
# s1         August 14, 2020          2020  TV-MA  4 Seasons
# s2       December 23, 2016          2016  TV-MA     93 min
# s3       December 20, 2018          2011      R     78 min
# s4       November 16, 2017          2009  PG-13     80 min
# s5         January 1, 2020          2008  PG-13    123 min
#
#                                                  listed_in  \
# show_id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# s2                            Dramas, International Movies
# s3                     Horror Movies, International Movies
# s4       Action & Adventure, Independent Movies, Sci-Fi...
# s5                                                  Dramas
#
#                                                description
# show_id
# s1       In a future where the elite inhabit an island ...
# s2       After a devastating earthquake hits Mexico Cit...
# s3       When an army recruit is found dead, his fellow...
# s4       In a postapocalyptic world, rag-doll robots hi...
# s5       A brilliant group of students become card-coun...

# %%
# Fetching the middle five observations
df.iloc[((df.shape[0]//2) - 2):((df.shape[0]//2) + 3)]
# Out:
#             type            title      director  \
# show_id
# s3892      Movie        Mallesham         Raj R
# s3893      Movie       Mama's Boy    Amro Salah
# s3894    TV Show         Man Down           NaN
# s3895    TV Show  Man Like Mobeen           NaN
# s3896      Movie   Man of Tai Chi  Keanu Reeves
#
#                                                       cast  \
# show_id
# s3892       Jhansi, Priyadarshi Pullikonda, Ananya Nagalla
# s3893    Hesham Maged, Shikoo, Mohammed Tharwat, Mahmou...
# s3894    Greg Davies, Roisin Conaty, Jeany Spark, Gwyne...
# s3895                                                  NaN
# s3896    Keanu Reeves, Tiger Chen, Karen Mok, Simon Yam...
#
#                                  country         date_added  release_year  \
# show_id
# s3892                              India  November 20, 2019          2019
# s3893                              Egypt      July 10, 2020          2018
# s3894                     United Kingdom  November 30, 2017          2017
# s3895                     United Kingdom      April 1, 2020          2020
# s3896    United States, China, Hong Kong      July 26, 2018          2013
#
#         rating   duration                                         listed_in  \
# show_id
# s3892    TV-PG    131 min  Dramas, Independent Movies, International Movies
# s3893    TV-14    101 min                    Comedies, International Movies
# s3894    TV-MA  4 Seasons                     British TV Shows, TV Comedies
# s3895    TV-MA  3 Seasons                     British TV Shows, TV Comedies
# s3896        R    105 min                        Action & Adventure, Dramas
#
#                                                description
# show_id
# s3892    A self-trained engineer risks debt, love and r...
# s3893    A man undergoes a heart transplant following a...
# s3894    A childish idiot trapped in an adult's body, s...
# s3895    Mobeen is trying to be a good friend, follow t...
# s3896    In this kung fu tale set in Beijing, a young m...

# %%
# Fetching the last five observations
df.tail()
# Out:
#             type                                    title     director  \
# show_id
# s7783      Movie                                     Zozo  Josef Fares
# s7784      Movie                                   Zubaan  Mozez Singh
# s7785      Movie                        Zulu Man in Japan          NaN
# s7786    TV Show                    Zumbo's Just Desserts          NaN
# s7787      Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                       cast  \
# show_id
# s7783    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# s7784    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# s7785                                              Nasty C
# s7786                           Adriano Zumbo, Rachel Khoo
# s7787                                                  NaN
#
#                                                    country  \
# show_id
# s7783    Sweden, Czech Republic, United Kingdom, Denmar...
# s7784                                                India
# s7785                                                  NaN
# s7786                                            Australia
# s7787                United Kingdom, Canada, United States
#
#                  date_added  release_year rating  duration  \
# show_id
# s7783      October 19, 2020          2005  TV-MA    99 min
# s7784         March 2, 2019          2015  TV-14   111 min
# s7785    September 25, 2020          2019  TV-MA    44 min
# s7786      October 31, 2020          2019  TV-PG  1 Season
# s7787         March 1, 2020          2019  TV-MA    90 min
#
#                                                  listed_in  \
# show_id
# s7783                         Dramas, International Movies
# s7784       Dramas, International Movies, Music & Musicals
# s7785    Documentaries, International Movies, Music & M...
# s7786                   International TV Shows, Reality TV
# s7787                      Documentaries, Music & Musicals
#
#                                                description
# show_id
# s7783    When Lebanon's Civil War deprives Zozo of his ...
# s7784    A scrappy but poor boy worms his way into a ty...
# s7785    In this documentary, South African rapper Nast...
# s7786    Dessert wizard Adriano Zumbo looks for the nex...
# s7787    This documentary delves into the mystique behi...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f'The Netflix dataset contain {df.shape[0]} Records and {df.shape[1]} Features')
# Out:
# The Netflix dataset contain 7787 Records and 11 Features

# %%
# column names
col_list = list(df.columns)

# Iterate through each columns just to format
for num, col in enumerate(col_list):
    print(f'{col} is the {num+1} feature in the dataset')
    print('*'*50)
# Out:
# type is the 1 feature in the dataset
# **************************************************
# title is the 2 feature in the dataset
# **************************************************
# director is the 3 feature in the dataset
# **************************************************
# cast is the 4 feature in the dataset
# **************************************************
# country is the 5 feature in the dataset
# **************************************************
# date_added is the 6 feature in the dataset
# **************************************************
# release_year is the 7 feature in the dataset
# **************************************************
# rating is the 8 feature in the dataset
# **************************************************
# duration is the 9 feature in the dataset
# **************************************************
# listed_in is the 10 feature in the dataset
# **************************************************
# description is the 11 feature in the dataset
# **************************************************

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
# Let's get the basic info about the dataset
# Covering with the datafrmame for better output
info_df = pd.DataFrame(df.info())

# Show the info  
info_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, s1 to s7787
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          7787 non-null   object
#  1   title         7787 non-null   object
#  2   director      5398 non-null   object
#  3   cast          7069 non-null   object
#  4   country       7280 non-null   object
#  5   date_added    7777 non-null   object
#  6   release_year  7787 non-null   int64
#  7   rating        7780 non-null   object
#  8   duration      7787 non-null   object
#  9   listed_in     7787 non-null   object
#  10  description   7787 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 730.0+ KB
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(f"The total number of duplicated observations in the dataset: {df.duplicated().sum()}")
# Out:
# The total number of duplicated observations in the dataset: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Counting the null values
null_df = pd.DataFrame(df.isnull().sum(), columns=['Null_Value_Count'])

# Calculating the percentage of null values
null_df['Null_Value_Percentage'] = ((null_df['Null_Value_Count'] / len(df)) * 100).round(2).astype(str) + '%'

# Sorting the results
null_df = null_df.sort_values(by='Null_Value_Count', ascending=False)

# printing the final result
null_df
# Out:
#               Null_Value_Count Null_Value_Percentage
# director                  2389                30.68%
# cast                       718                 9.22%
# country                    507                 6.51%
# date_added                  10                 0.13%
# rating                       7                 0.09%
# type                         0                  0.0%
# title                        0                  0.0%
# release_year                 0                  0.0%
# duration                     0                  0.0%
# listed_in                    0                  0.0%
# description                  0                  0.0%

# %%
# Sorting the results
null_df = null_df.sort_values(by='Null_Value_Count', ascending=False)

# Creating the vertical bar chart
plt.barh(null_df.index, null_df['Null_Value_Count'])

# Setting the y-axis scale to log scale
plt.xscale('log')

# Adding annotations with count of null values in each bar
for i, v in enumerate(null_df['Null_Value_Count']):
    plt.text(v + 1, i, str(v), fontsize=10)

# Adding labels and title
plt.xlabel('Null Value Count (log scale)')
plt.ylabel('Columns')
plt.title('Distribution of Null Values')

# Displaying the chart
plt.show()

# %%
# Visualize the correlation between the number of
# missing values in different columns as a heatmap
# Define a custom color palette with 5 distinct colors
colors = sns.color_palette('Set3', n_colors=5)

# Create the heatmap with the custom color palette
msno.heatmap(df, figsize=(10,5), cmap=colors)
# Out:
# <Axes: >

# %% [markdown]
# > The heatmap has columns and rows representing the columns in the DataFrame, and each cell in the heatmap represents the correlation between the missing values in two columns. The color of each cell indicates the strength of the correlation.
#
# > It is useful tool for understanding patterns of missing data in a DataFrame and identifying which columns tend to have missing values together.
#
# > And, form the above plot it is clear that there is <b>no correlation between missing of columns.</b>

# %% [markdown]
# ### What did you know about your dataset?

# %%
# let's create a custom function to create a dataframe which contain the metadata of the dataset
# define a function.
def metainfo(given_df):
  
  # doc string contain a short description about the function useability.
  '''This function return the new dataframe called meta_structure, & gives metadata about dataframe.

  Parameters:
        df (pandas.DataFrame): Input DataFrame.

    Returns:
        pandas.DataFrame with customized features.
  
  '''
  
  # we want each attribute of the dataframe as a row in new datafrme.
  meta_structure = pd.DataFrame(index=given_df.columns)

  # let's create a six new column which defines our metadata.
  meta_structure["data_type"] = given_df.dtypes
  meta_structure["not_null_values"] = given_df.count()
  meta_structure["null_values"] = given_df.isnull().sum()
  meta_structure["null_values_percentage"] = round(given_df.isnull().mean(),5) * 100
  meta_structure["unique_count"] = given_df.nunique()
  meta_structure["duplicated_count"] = given_df.shape[0] - given_df.nunique()

  # just return the created structure.
  return meta_structure

# %%
# function calling.
metainfo_df = metainfo(df)

# let's print the meta_df
metainfo_df
# Out:
#              data_type  not_null_values  null_values  null_values_percentage  \
# type            object             7787            0                   0.000
# title           object             7787            0                   0.000
# director        object             5398         2389                  30.679
# cast            object             7069          718                   9.220
# country         object             7280          507                   6.511
# date_added      object             7777           10                   0.128
# release_year     int64             7787            0                   0.000
# rating          object             7780            7                   0.090
# duration        object             7787            0                   0.000
# listed_in       object             7787            0                   0.000
# description     object             7787            0                   0.000
#
#               unique_count  duplicated_count
# type                     2              7785
# title                 7787                 0
# director              4049              3738
# cast                  6831               956
# country                681              7106
# date_added            1565              6222
# release_year            73              7714
# rating                  14              7773
# duration               216              7571
# listed_in              492              7295
# description           7769                18

# %% [markdown]
# >From the Initial inspection of the dataset we gather the following points :
#
# >1. The netflix daaset contains 7787 records.
# >2. These records are distributed among 11 features.
# >3. Each single record is contain the information about a perticular film.
# >4. We won't find any duplicate values in the dataset.
# >5. We also won't find any duplicate titles of the movies in dataset.
# >6. We found 18 records which having same description in dataset.
# >7. The <b>'type'</b> feature only contain two discrete values as <b>Movie</b> or <b>TV Show</b>.
# >8. There are five feature which contain the null values those are :<br> - <b>director : 30.68%</b><br>- <b>cast : 9.22%</b><br>- <b>country : 6.51%</b><br>- <b>date_added : 0.13%</b><br>- <b>rating : 0.09%</b><br>
# >9. The <b>data_added</b> feature need a data type correction form object to datatime.
# >10. There are 681 countries where netflix stream there services.
# >11. The dataset contain 14 unique rating criteria for movies or TV shows.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
def create_num_col_dict(df):
    '''
    The function returns the columns name with dataframe
    '''
    # Created the column name list
    col_list = list(df.columns)

    # Created the assigned number list
    num_list = [ i for i in range(1, 17)]

    # Create the empty dictionary which contain key as column number
    # and value as column name.
    num_col_dict = {}

    # Let's iterate through each pair and add it to the dictionary
    for i, j in zip(num_list, col_list):
        num_col_dict[i] = j

    # Convert the dictionary to a pandas DataFrame
    num_col_df = pd.DataFrame.from_dict(num_col_dict, orient='index', columns=['Column_Name'])

    return num_col_df

# %%
# Function calling
create_num_col_dict(df)
# Out:
#      Column_Name
# 1           type
# 2          title
# 3       director
# 4           cast
# 5        country
# 6     date_added
# 7   release_year
# 8         rating
# 9       duration
# 10     listed_in
# 11   description

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#          type title                 director                cast  \
# count    7787  7787                     5398                7069
# unique      2  7787                     4049                6831
# top     Movie    3%  RaÃºl Campos, Jan Suter  David Attenborough
# freq     5377     1                       18                  18
# mean      NaN   NaN                      NaN                 NaN
# std       NaN   NaN                      NaN                 NaN
# min       NaN   NaN                      NaN                 NaN
# 25%       NaN   NaN                      NaN                 NaN
# 50%       NaN   NaN                      NaN                 NaN
# 75%       NaN   NaN                      NaN                 NaN
# max       NaN   NaN                      NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            7280             7777   7787.000000   7780      7787
# unique            681             1565           NaN     14       216
# top     United States  January 1, 2020           NaN  TV-MA  1 Season
# freq             2555              118           NaN   2863      1608
# mean              NaN              NaN   2013.932580    NaN       NaN
# std               NaN              NaN      8.757395    NaN       NaN
# min               NaN              NaN   1925.000000    NaN       NaN
# 25%               NaN              NaN   2013.000000    NaN       NaN
# 50%               NaN              NaN   2017.000000    NaN       NaN
# 75%               NaN              NaN   2018.000000    NaN       NaN
# max               NaN              NaN   2021.000000    NaN       NaN
#
#             listed_in                                        description
# count            7787                                               7787
# unique            492                                               7769
# top     Documentaries  Multiple women report their husbands as missin...
# freq              334                                                  3
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN

# %% [markdown]
# The output includes the following statistics for the numerical columns:
#
# > - count: number of non-missing values in the column
# > - mean: average value of the column
# > - std: standard deviation of the column
# > - min: minimum value of the column
# > - 25%: first quartile or 25th percentile of the column
# > - 50%: median or 50th percentile of the column
# > - 75%: third quartile or 75th percentile of the column
# > - max: maximum value of the column
#
# For the non-numerical columns, we get the following information:
#
# > - count: number of non-missing values in the column
# > - unique: number of unique values in the column
# > - top: most common value in the column
# > - freq: frequency of the most common value in the column
#
# ---
#
# >* The only featue which is numerial one is <b>release_year</b> and all the other featues are non-numerical one.
# >* The dataset contian the movies which are released between <b>1925 to 2021.</b>
# >* The genre where most movies are listed is <b>Documentaries</b>.
# >* The most frequent rating is <b>TV-MA (Mature Audience Only)</b> which is given <b>2863 times</b>.
# >* The country which produces most of the content in the dataset is <b>United States</b>.
# >* The dataset contain most of the <b>movies</b> which is accounted to <b>5377 times</b>.
# >* Most of the content are available on <b>$1^{st} - Jan - 2020$</b> which is accounted to <b>118</b>.

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The variable description of the Netflix Movies and TV Shows Clustering Dataset is as follows:
#
# 1. **show_id**: Unique identifier for each movie/show.
#
# 2. **type**: Indicates whether the entry is a movie or a TV show.
#
# 3. **title**: Name of the movie or TV show.
#
# 4. **director**: Name of the director(s) of the movie or TV show.
#
# 5. **cast**: Names of the actors and actresses featured in the movie or TV show.
#
# 6. **country**: Country or countries where the movie or TV show was produced.
#
# 7. **date_added**: Date when the movie or TV show was added to Netflix.
#
# 8. **release_year**: Year when the movie or TV show was released.
#
# 9. **rating**: TV rating or movie rating of the movie or TV show.
#
# 10. **duration**: Length of the movie or TV show in minutes or seasons.
#
# 11. **listed_in**: Categories or genres of the movie or TV show.
#
# 12. **description**: Brief synopsis or summary of the movie or TV show.

# %% [markdown]
# #### <b>The Flavors Of Data And The Scales Of Data Measurement</b>
#
# >* Before, we start our analysis it better to discuss the flavors of data and it's scales of measurement. It is important to discuss this topic because for each type of scale the methodology for statistical analysis will be changed.
#
# ##### <b>Flavors of data</b>
# <br>
# <center><img src="https://github.com/ashish-mali/Netflix-Movies-And-TV-Shows-Clustering/blob/main/Images/type_of_data.jpg?raw=true" alt="Types of Data" width="auto" height="auto"></center>
# <br>
#
# >* It is important to understand the different flavors of data for several reasons. Not only will the type of data dictate the method used to analyze and extract results. knowing whether the data is unstructured or perhaps quantitative can also tell you a lot about the real-world phenomenon being measured. Let's look at the three basic classification of data :
#
# >>* Structured vs Unstructured $/$ (Organized vs Unorganized).
#
# >>* Quantitative vs Qualitative.
#
# >>>* Nominal data.
# >>>*Ordinal data.
# >>>*Discrete data.
# >>>*Continuous data.
#
# ##### <b>The scales of data measurement</b>
# <br>
# <center><img src="https://github.com/ashish-mali/Netflix-Movies-And-TV-Shows-Clustering/blob/main/Images/level_of_data.jpg?raw=true" alt="Level of Data" width="800" height="auto"></center>
# <br>
#
# >* It is generally understood that a specific characteristic (feature / column) of structured data can be broken down into aone of four levels of data. As we move form Nominal to Ratio, we gain more structure and therefore more returns from our analysis. Each level comes with it's own accepted practicve in measuring the conter of the data. We usually think of the mean/average as being an acceptable form of center, howerver, this is only true for a specific type of data.
#
# >* Let's define our given feature by usign the above frameworks.
#
# >>* <b>type :-</b> This feature has a  data type of <u>Categorical - Nominal</u> and scale is <u>Nominal</u>.
# >>* <b>title :-</b> This feature has a  data type of <u>Categorical - Nominal</u> and scale is <u>Nominal</u>.
# >>* <b>director :-</b>This feature has a  data type of <u>Categorical - Nominal</u> and scale is <u>Nominal</u>.
# >>* <b>cast :-</b>This feature has a  data type of <u>Categorical - Nominal</u> and scale is <u>Nominal</u>.
# >>* <b>country :-</b>This feature has a  data type of <u>Categorical - Nominal</u> and scale is <u>Nominal</u>.
# >>* <b>date_added :-</b> This feature has a  data type of <u>Quantitative - Ordinal</u> and scale is <u>Interval level</u>.
# >>* <b>release_year :-</b> This feature has a  data type of <u>Quantitative - Ordinal</u> and scale is <u>Interval level</u>.
# >>* <b>rating :-</b>This feature has a  data type of <u>Quantitative - Continuous</u> and scale is <u>Ratio level</u>.
# >>* <b>duration :-</b>This feature has a  data type of <u>Quantitative - Continuous</u> and scale is <u>Ratio level</u>.
# >>* <b>listed_in :-</b>This feature has a  data type of <u>Quantitative - Ordinal</u> and scale is <u>Interval level</u>.
# >>* <b>description :-</b>This feature has a  data type of <u>Categorical - Nominal</u> and scale is <u>Nominal</u>.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
def display_unique_values(df):
    # Loop through each column in the dataframe
    for column in df.columns:
        # Get the unique values for the current column
        unique_values = df[column].nunique()
        # Print the feature name, unique values, and value counts for the current column
        print(f"Feature Name: {column}")
        print(f"Unique Values: {unique_values}")
        print('='*50)

# %%
# Function calling
display_unique_values(df)
# Out:
# Feature Name: type
# Unique Values: 2
# ==================================================
# Feature Name: title
# Unique Values: 7787
# ==================================================
# Feature Name: director
# Unique Values: 4049
# ==================================================
# Feature Name: cast
# Unique Values: 6831
# ==================================================
# Feature Name: country
# Unique Values: 681
# ==================================================
# Feature Name: date_added
# Unique Values: 1565
# ==================================================
# Feature Name: release_year
# Unique Values: 73
# ==================================================
# Feature Name: rating
# Unique Values: 14
# ==================================================
# Feature Name: duration
# Unique Values: 216
# ==================================================
# Feature Name: listed_in
# Unique Values: 492
# ==================================================
# Feature Name: description
# Unique Values: 7769
# ==================================================

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# #### 1. Handling of Null/Misssing Data Points.

# %%
# Fetching already created null value data frame
null_df
# Out:
#               Null_Value_Count Null_Value_Percentage
# director                  2389                30.68%
# cast                       718                 9.22%
# country                    507                 6.51%
# date_added                  10                 0.13%
# rating                       7                 0.09%
# type                         0                  0.0%
# title                        0                  0.0%
# release_year                 0                  0.0%
# duration                     0                  0.0%
# listed_in                    0                  0.0%
# description                  0                  0.0%

# %% [markdown]
# <b>Ways to handle the null values in the dataset.</b>
#
# > <b>Director -</b> As around 31% of the director data is missing, it is challenging to impute the values. One possible solution is to replace the missing values with a string such as 'unknown,' or 'not available,' to indicate the unavailability of data.
#
# > <b>Cast -</b> Since only around 9% of the cast data is missing, one possible approach is to replace missing values with the most frequently occurring cast member, or the cast member who appears in the most similar movies or TV shows. Another solution is to drop the rows with missing values.
#
# > <b>Country -</b> As around 6.5% of country data is missing, one possible solution is to replace missing values with the most frequently occurring country in the dataset, or with the country that produces the most similar movies or TV shows. Another solution is to drop the rows with missing values.
#
# > <b>Date_added -</b> With only 0.13% of missing values, it is possible to replace missing values with the mode (most common value) of the date_added feature. Alternatively, the missing values can be filled with the average or median of the date_added column.
#
# > <b>Rating -</b> With only 0.09% of missing values, it is possible to replace missing values with the mode (most common value) of the rating feature. Alternatively, the missing values can be filled with the average or median of the rating column.
#
# > <b>Type</b>, <b>title</b>, <b>release_year</b>, <b>duration</b>,  <b>listed_in</b>, and <b>description</b> - Since these features have no missing values, no action is necessary.
#
# > So, after discussing the ways to handle the null values we finalize the following things:
#  >> 1. For the <b>Director, Cast, Country</b> features the best way is to get values with any of the valid data source but as we don't have the secondery data resources to follow on, the <b>next best case it to impute the missing value with string labled as "unknown"</b> by doing so we retain most of the data.
#  >> 2. For the other features i.e <b>Date_added, Rating</b> we decided to <b>drop the values</b> and the percentage is very low and droping won't have significant information loss.

# %%
# For the director, cast, country imputed null values with "unknown"
df[['director', 'cast', 'country']] = df[['director', 'cast', 'country']].fillna("Unknown")

# %%
# features which has less than 1%  null values present. 
nan_columns = ['date_added', 'rating']

# dropping null values
df.dropna(subset=nan_columns, inplace=True)

# %%
# Checking the reflection
pd.DataFrame(df.isna().sum(), columns=["count_null_values"])
# Out:
#               count_null_values
# type                          0
# title                         0
# director                      0
# cast                          0
# country                       0
# date_added                    0
# release_year                  0
# rating                        0
# duration                      0
# listed_in                     0
# description                   0

# %% [markdown]
# > -  We can conclude that we successfully eleminated the null/missing values in the dataset.

# %% [markdown]
# #### 2. Duplicate value treatment.

# %%
# Let's get count of  duplicated values
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# > - The dataset is free from duplicated values.

# %%
df.head()
# Out:
#             type  title           director  \
# show_id
# s1       TV Show     3%            Unknown
# s2         Movie   7:19  Jorge Michel Grau
# s3         Movie  23:59       Gilbert Chan
# s4         Movie      9        Shane Acker
# s5         Movie     21     Robert Luketic
#
#                                                       cast        country  \
# show_id
# s1       JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# s2       DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#                 date_added  release_year rating   duration  \
# show_id
# s1         August 14, 2020          2020  TV-MA  4 Seasons
# s2       December 23, 2016          2016  TV-MA     93 min
# s3       December 20, 2018          2011      R     78 min
# s4       November 16, 2017          2009  PG-13     80 min
# s5         January 1, 2020          2008  PG-13    123 min
#
#                                                  listed_in  \
# show_id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# s2                            Dramas, International Movies
# s3                     Horror Movies, International Movies
# s4       Action & Adventure, Independent Movies, Sci-Fi...
# s5                                                  Dramas
#
#                                                description
# show_id
# s1       In a future where the elite inhabit an island ...
# s2       After a devastating earthquake hits Mexico Cit...
# s3       When an army recruit is found dead, his fellow...
# s4       In a postapocalyptic world, rag-doll robots hi...
# s5       A brilliant group of students become card-coun...

# %% [markdown]
# #### 3. Handling the features having Nested lists.

# %%
# Let's create a copy of dataframe and unnest the original one
df_new= df.copy()

# %% [markdown]
# ##### A. Directors Feature

# %%
# Unnesting 'Directors' column
dir_constraint=df['director'].apply(lambda x: str(x).split(', ')).tolist()
df1 = pd.DataFrame(dir_constraint, index = df['title']) 
df1 = df1.stack()
df1 = pd.DataFrame(df1.reset_index())
df1.rename(columns={0:'Directors'},inplace=True)
df1 = df1.drop(['level_1'],axis=1)

# Show the reflection
df1.sample(10)
# Out:
#                                            title              Directors
# 8033                                      V Wars                Unknown
# 5258         Pioneers of African-American Cinema        Richard Maurice
# 4792                                      Ne Zha                Yu Yang
# 4287  Mau Nieto: Viviendo sobrioâ¦ desde el bar                Unknown
# 714                              BabamÄ±n Ceketi  MÃ¼fit Can SaÃ§Ä±ntÄ±
# 8191                             Weed the People           Abby Epstein
# 6643                       The Beginning of Life          Estela Renner
# 4484                                         Mom           Ravi Udyawar
# 7901                               Truth or Dare             Nick Simon
# 8462                                       Zenda         Avadhoot Gupte

# %% [markdown]
# ##### B. Cast Feature

# %%
# Unnesting 'cast' column
cast_constraint=df['cast'].apply(lambda x: str(x).split(', ')).tolist()
df2 = pd.DataFrame(cast_constraint, index = df['title']) 
df2 = df2.stack()
df2 = pd.DataFrame(df2.reset_index())
df2.rename(columns={0:'Actors'},inplace=True)
df2 = df2.drop(['level_1'],axis=1)

# Show the reflection
df2.sample(10)
# Out:
#                                           title                  Actors
# 46757                             The Influence          Claudia Placer
# 51177                                    Thithi           Abhishek H.N.
# 15525                                     Farce        Mohammed Tharwat
# 28938                           Men in Black II        Johnny Knoxville
# 33440                           Ordinary Heroes        Lorenza Indovina
# 2332                             Action Replayy  Aishwarya Rai Bachchan
# 6943                                   Bird Box           Tom Hollander
# 23406                                   Junebug             Jerry Minor
# 38300    Sam Kinison: Family Entertainment Hour             Sam Kinison
# 44233  The Boys in the Band: Something Personal          Zachary Quinto

# %% [markdown]
# ##### C. Listed_In Feature

# %%
# Unnesting 'listed_in' column
listed_constraint=df['listed_in'].apply(lambda x: str(x).split(', ')).tolist()
df3 = pd.DataFrame(listed_constraint, index = df['title']) 
df3 = df3.stack()
df3 = pd.DataFrame(df3.reset_index())
df3.rename(columns={0:'Genre'},inplace=True)
df3 = df3.drop(['level_1'],axis=1)

# Show the reflection
df3.sample(10)
# Out:
#                               title                      Genre
# 14554        The Matrix Revolutions           Sci-Fi & Fantasy
# 9714       Nature's Weirdest Events        Science & Nature TV
# 15951  Ultimate Beastmaster MÃ©xico  Spanish-Language TV Shows
# 1872       Best.Worst.Weekend.Ever.                   Kids' TV
# 328                    A 2nd Chance   Children & Family Movies
# 6769                  Itaewon Class     International TV Shows
# 3567                    DASH & LILY                  TV Dramas
# 1144                Animal Crackers   Children & Family Movies
# 16875                   Yoga Hosers              Horror Movies
# 11185                  Razia Sultan                  TV Dramas

# %% [markdown]
# ##### D. Country Feature

# %%
# Unnesting 'country' column
country_constraint=df['country'].apply(lambda x: str(x).split(', ')).tolist()
df4 = pd.DataFrame(country_constraint, index = df['title']) 
df4 = df4.stack()
df4 = pd.DataFrame(df4.reset_index())
df4.rename(columns={0:'Country'},inplace=True)
df4 = df4.drop(['level_1'],axis=1)

# Show the reflection
df4.sample(10)
# Out:
#                                                 title         Country
# 393                                         Aftermath  United Kingdom
# 3075                                           Grease   United States
# 7717                              The Florida Project   United States
# 3669                                            Insan           India
# 4672                                Making a Murderer   United States
# 662         Antoine Griezmann: The Making of a Legend         Unknown
# 1571                                  Chashme Baddoor           India
# 4698                                            Mandi           India
# 2267  Dragons: Rescue Riders: Secrets of the Songwing   United States
# 896                          Barbie in Rock 'N Royals   United States

# %% [markdown]
# > - As  we have sucessfully separated the nested columns. Now let's just merge all the created dataframe into the single merged dataframe.

# %% [markdown]
# ##### E. Merging Operation

# %%
## Merging all the unnested dataframes
# Merging director and cast
df5 = df2.merge(df1,on=['title'],how='inner')

# Merging listed_in with merged of (director and cast)
df6 = df5.merge(df3,on=['title'],how='inner')

# Merging country with merged of [listed_in with merged of (director and cast)]
df7 = df6.merge(df4,on=['title'],how='inner')

# Head of final merged dataframe
df7.head()
# Out:
#   title            Actors Directors                   Genre Country
# 0    3%      JoÃ£o Miguel   Unknown  International TV Shows  Brazil
# 1    3%      JoÃ£o Miguel   Unknown               TV Dramas  Brazil
# 2    3%      JoÃ£o Miguel   Unknown     TV Sci-Fi & Fantasy  Brazil
# 3    3%  Bianca Comparato   Unknown  International TV Shows  Brazil
# 4    3%  Bianca Comparato   Unknown               TV Dramas  Brazil

# %% [markdown]
# >* Now, let's merge this dataframe with the original one on the left join to avoid information loss.

# %%
# Merging unnested data with the created dataframe in order to make the final dataframe
df = df7.merge(df[['type', 'title', 'date_added', 'release_year', 'rating', 'duration','description']],on=['title'],how='left')

# Checking the reflection
df.head()
# Out:
#   title            Actors Directors                   Genre Country     type  \
# 0    3%      JoÃ£o Miguel   Unknown  International TV Shows  Brazil  TV Show
# 1    3%      JoÃ£o Miguel   Unknown               TV Dramas  Brazil  TV Show
# 2    3%      JoÃ£o Miguel   Unknown     TV Sci-Fi & Fantasy  Brazil  TV Show
# 3    3%  Bianca Comparato   Unknown  International TV Shows  Brazil  TV Show
# 4    3%  Bianca Comparato   Unknown               TV Dramas  Brazil  TV Show
#
#         date_added  release_year rating   duration  \
# 0  August 14, 2020          2020  TV-MA  4 Seasons
# 1  August 14, 2020          2020  TV-MA  4 Seasons
# 2  August 14, 2020          2020  TV-MA  4 Seasons
# 3  August 14, 2020          2020  TV-MA  4 Seasons
# 4  August 14, 2020          2020  TV-MA  4 Seasons
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  In a future where the elite inhabit an island ...
# 2  In a future where the elite inhabit an island ...
# 3  In a future where the elite inhabit an island ...
# 4  In a future where the elite inhabit an island ...

# %% [markdown]
# #### 4. Correcting the data types

# %%
# Data types of  each of the features
pd.DataFrame(df.dtypes, columns=['dtypes'])
# Out:
#               dtypes
# title         object
# Actors        object
# Directors     object
# Genre         object
# Country       object
# type          object
# date_added    object
# release_year   int64
# rating        object
# duration      object
# description   object

# %%
# Typecasting duration into integer by removing 'min' and 'season' from the end
df['duration']= df['duration'].apply(lambda x: int(x.split()[0]))

# %%
# Typecasting string object to datetime object of date_added column
df['date_added']= pd.to_datetime(df['date_added'])

# %%
# Extracting date, day, month and year from date_added column
df["day_added"]= df["date_added"].dt.day
df["month_added"]= df["date_added"].dt.month
df["year_added"]= df["date_added"].dt.year

# %%
# Dropping date_added
df.drop('date_added', axis=1, inplace=True)

# %%
# Dataframe wiith newly created featurtes
df.head()
# Out:
#   title            Actors Directors                   Genre Country     type  \
# 0    3%      JoÃ£o Miguel   Unknown  International TV Shows  Brazil  TV Show
# 1    3%      JoÃ£o Miguel   Unknown               TV Dramas  Brazil  TV Show
# 2    3%      JoÃ£o Miguel   Unknown     TV Sci-Fi & Fantasy  Brazil  TV Show
# 3    3%  Bianca Comparato   Unknown  International TV Shows  Brazil  TV Show
# 4    3%  Bianca Comparato   Unknown               TV Dramas  Brazil  TV Show
#
#    release_year rating  duration  \
# 0          2020  TV-MA         4
# 1          2020  TV-MA         4
# 2          2020  TV-MA         4
# 3          2020  TV-MA         4
# 4          2020  TV-MA         4
#
#                                          description  day_added  month_added  \
# 0  In a future where the elite inhabit an island ...         14            8
# 1  In a future where the elite inhabit an island ...         14            8
# 2  In a future where the elite inhabit an island ...         14            8
# 3  In a future where the elite inhabit an island ...         14            8
# 4  In a future where the elite inhabit an island ...         14            8
#
#    year_added
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020

# %%
# check if release_year and year_added are same or not
print(df['release_year'].equals(df['year_added']))
# Out:
# False

# %%
# Checking the reflection
pd.DataFrame(df.dtypes, columns=['dtypes'])
# Out:
#               dtypes
# title         object
# Actors        object
# Directors     object
# Genre         object
# Country       object
# type          object
# release_year   int64
# rating        object
# duration       int64
# description   object
# day_added      int64
# month_added    int64
# year_added     int64

# %% [markdown]
# #### 5. Handling  the Units of Duration Feature

# %%
# Let's do a value count over the duration feature
duration_valuecouts = pd.DataFrame(df['duration'].value_counts())

# %%
# Checking reflection
duration_valuecouts.sample(10)
# Out:
#      duration
# 194        30
# 81       1149
# 169        34
# 140       560
# 120      1502
# 67         63
# 50         34
# 174        53
# 209        40
# 96       3140

# %% [markdown]
# > - From above it's very clear that :
# >> - The duration of the Movies are in the <b>min</b>
# >> - the duration of the TV Shows are in the form of <b>Season</b>
# > - To handle this we have to create the sepetate the data frame for these two for better analysis.

# %%
# Spearating the dataframes for further analysis
df_movies= df[df['type']== 'Movie']
df_tvshows= df[df['type']== 'TV Show']

# %%
# Checking reflection
df_movies.head()
# Out:
#    title           Actors          Directors                 Genre Country  \
# 33  7:19   DemiÃ¡n Bichir  Jorge Michel Grau                Dramas  Mexico
# 34  7:19   DemiÃ¡n Bichir  Jorge Michel Grau  International Movies  Mexico
# 35  7:19  HÃ©ctor Bonilla  Jorge Michel Grau                Dramas  Mexico
# 36  7:19  HÃ©ctor Bonilla  Jorge Michel Grau  International Movies  Mexico
# 37  7:19    Oscar Serrano  Jorge Michel Grau                Dramas  Mexico
#
#      type  release_year rating  duration  \
# 33  Movie          2016  TV-MA        93
# 34  Movie          2016  TV-MA        93
# 35  Movie          2016  TV-MA        93
# 36  Movie          2016  TV-MA        93
# 37  Movie          2016  TV-MA        93
#
#                                           description  day_added  month_added  \
# 33  After a devastating earthquake hits Mexico Cit...         23           12
# 34  After a devastating earthquake hits Mexico Cit...         23           12
# 35  After a devastating earthquake hits Mexico Cit...         23           12
# 36  After a devastating earthquake hits Mexico Cit...         23           12
# 37  After a devastating earthquake hits Mexico Cit...         23           12
#
#     year_added
# 33        2016
# 34        2016
# 35        2016
# 36        2016
# 37        2016

# %%
# Checking reflection
df_tvshows.head()
# Out:
#   title            Actors Directors                   Genre Country     type  \
# 0    3%      JoÃ£o Miguel   Unknown  International TV Shows  Brazil  TV Show
# 1    3%      JoÃ£o Miguel   Unknown               TV Dramas  Brazil  TV Show
# 2    3%      JoÃ£o Miguel   Unknown     TV Sci-Fi & Fantasy  Brazil  TV Show
# 3    3%  Bianca Comparato   Unknown  International TV Shows  Brazil  TV Show
# 4    3%  Bianca Comparato   Unknown               TV Dramas  Brazil  TV Show
#
#    release_year rating  duration  \
# 0          2020  TV-MA         4
# 1          2020  TV-MA         4
# 2          2020  TV-MA         4
# 3          2020  TV-MA         4
# 4          2020  TV-MA         4
#
#                                          description  day_added  month_added  \
# 0  In a future where the elite inhabit an island ...         14            8
# 1  In a future where the elite inhabit an island ...         14            8
# 2  In a future where the elite inhabit an island ...         14            8
# 3  In a future where the elite inhabit an island ...         14            8
# 4  In a future where the elite inhabit an island ...         14            8
#
#    year_added
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020

# %% [markdown]
# > * let's just quickly check the records and observation of newly created dataframes.

# %%
# Checking for  dataframe which only contain movies
print(f'For the only movies dataframe: Records= {df_movies.shape[0]}, and Features = {df_movies.shape[1]}')
# Out:
# For the only movies dataframe: Records= 126079, and Features = 13

# %%
# Checking for  dataframe which only contain tv shows
print(f'For the only movies dataframe: Records= {df_tvshows.shape[0]}, and Features = {df_tvshows.shape[1]}')
# Out:
# For the only movies dataframe: Records= 49728, and Features = 13

# %% [markdown]
# #### 6. Fixing the Range of Rating Feature

# %%
pd.DataFrame(df['rating'].value_counts())
# Out:
#           rating
# TV-MA      64510
# TV-14      39087
# R          21608
# TV-PG      13649
# PG-13      13304
# PG          9073
# TV-Y7       5357
# TV-Y        3183
# TV-G        2512
# NR          1666
# G           1429
# UR           194
# NC-17        149
# TV-Y7-FV      86

# %% [markdown]
# These are content ratings used by Netflix to help viewers understand the appropriate audience for a particular TV show or movie. Here's what each rating means:
#
# > <b>TV-MA (Mature Audience):</b> This program is intended for mature audiences and may not be suitable for children under 17.
#
# > <b>TV-14 (Parents Strongly Cautioned):</b> This program may contain material that is inappropriate for children under 14.
#
# > <b>R (Restricted):</b> This movie is intended for mature audiences and may not be suitable for children under 17. Children under 17 require accompanying parent or adult guardian.
#
# > <b>TV-PG (Parental Guidance Suggested):</b> This program may contain material that parents may find unsuitable for younger children.
#
# > <b>PG-13 (Parents Strongly Cautioned):</b> This program may contain material that is inappropriate for children under 13.
#
# > <b>PG (Parental Guidance Suggested):</b> This program may contain material that parents may find unsuitable for younger children.
#
# > <b>TV-Y7 (Directed to Older Children):</b> This program is designed for children age 7 and above.
#
# > <b>TV-Y (Designed for Young Children):</b> This program is designed for children of all ages.
#
# > <b>TV-G (General Audience):</b> This program is suitable for all ages.
# NR (Not Rated): This program has not been rated.
#
# > <b>G (General Audience):</b> This program is suitable for all ages.
#
# > <b>UR (Unrated):</b> This movie has not been rated by the Motion Picture Association of America (MPAA).
#
# > <b>NC-17 (No Children Under 17):</b> This movie is intended for mature audiences and may not be suitable for children under 17.
#
# > <b>TV-Y7-FV (Directed to Older Children - Fantasy Violence):</b> This program is designed for children age 7 and above and may contain fantasy violence.

# %% [markdown]
# ##### Categorization Techniques

# %% [markdown]
# Let's categorize different content ratings that are similar to each other, based on their intended audience and level of content:
#
# >* <b>TV-Y, TV-Y7, TV-Y7-FV, TV-G:</b> These ratings are all intended for children and are generally suitable for all ages.
#
# >* <b>TV-PG, PG:</b> These ratings indicate that parental guidance is suggested and that some material may not be suitable for all children.
#
# >* <b>TV-14, PG-13:</b> These ratings are intended for older children and teenagers, as they may contain material that is inappropriate for younger viewers.
#
# >* <b>TV-MA, R, NC-17:</b> These ratings are intended for mature audiences and may contain graphic violence, sexual content, or language that is not suitable for children or younger viewers.
#
# >* <b>NR, UR:</b> These ratings indicate that a movie has not been rated by the MPAA or that it is unrated, respectively. This means that the content of the movie is not officially recognized by the MPAA, and viewers should exercise caution when watching it.
#
# Let's name all these categories
#
# >>* <b>Child-friendly ratings:</b> <code>TV-Y, TV-Y7, TV-Y7-FV, TV-G</code>
#
# >>* <b>Parental guidance suggested ratings:</b> <code>TV-PG, PG</code>
#
# >>* <b>Teen and older audience ratings:</b> <code>TV-14, PG-13</code>
#
# >>* <b>Mature audience ratings:<b> <code>TV-MA, R, NC-17</code>
#
# >>* <b>Unrated categories:</b> <code>NR, UR</code>

# %%
# Create a rating map for all the rating
rating_categories = {
    "TV-Y": "Child-friendly",
    "TV-Y7": "Child-friendly",
    "TV-Y7-FV": "Child-friendly",
    "TV-G": "Child-friendly",
    "G": "Child-friendly",
    "TV-PG": "Parental guidance",
    "PG": "Parental guidance",
    "TV-14": "Teen and older",
    "PG-13": "Teen and older",
    "TV-MA": "Mature",
    "R": "Mature",
    "NC-17": "Mature",
    "NR": "Unrated",
    "UR": "Unrated"
}

# %%
# Making chnages to the rating
df['rating'].replace(rating_categories, inplace = True)

# %%
# Checking reflection
df.head()
# Out:
#   title            Actors Directors                   Genre Country     type  \
# 0    3%      JoÃ£o Miguel   Unknown  International TV Shows  Brazil  TV Show
# 1    3%      JoÃ£o Miguel   Unknown               TV Dramas  Brazil  TV Show
# 2    3%      JoÃ£o Miguel   Unknown     TV Sci-Fi & Fantasy  Brazil  TV Show
# 3    3%  Bianca Comparato   Unknown  International TV Shows  Brazil  TV Show
# 4    3%  Bianca Comparato   Unknown               TV Dramas  Brazil  TV Show
#
#    release_year  rating  duration  \
# 0          2020  Mature         4
# 1          2020  Mature         4
# 2          2020  Mature         4
# 3          2020  Mature         4
# 4          2020  Mature         4
#
#                                          description  day_added  month_added  \
# 0  In a future where the elite inhabit an island ...         14            8
# 1  In a future where the elite inhabit an island ...         14            8
# 2  In a future where the elite inhabit an island ...         14            8
# 3  In a future where the elite inhabit an island ...         14            8
# 4  In a future where the elite inhabit an island ...         14            8
#
#    year_added
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020

# %%
df['rating'].unique()
# Out:
# array(['Mature', 'Teen and older', 'Parental guidance', 'Unrated',
#        'Child-friendly'], dtype=object)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# We have divided data wrangling into five different sections:
#
# 1. In this section we have imputed/drop the null values of:
#   * Imputed 'director' 'cast' and 'country' with 'Unknown'.
#   * Drop null values of 'date_added' and 'rating' (less percentage).
#
# 2. We have unnested values from following features:
#
#     * 'director'
#     * 'cast'
#     * 'listed_in'
#     * 'country'
#
#     * We have unnested the values and stored in different dataframes and then  merged all the dataframe with the original one using left join in order to get the isolated values of each of the feature.
#
# 3. Splitted the dataframe into two df one is 'df_movies' that contains only Movies and the other is 'df_tvshows' that contains only TV Shows for our further analysis.
#
# 4. * We have typecasted the following features:
#     * 'duration' into integer (Removing min and seasons from the values).
#     * 'date_added' to datetime (Into the required format).
#   * We have also extracted the following features:
#     * 'date' from 'date_added'.
#     * 'month' from 'date_added'.
#     * 'year' from 'date_added'.
#
# 5. We have seen that the 'rating' column contains various coded categories, so  we have decided to create 5 categories and distribute the values accordingly:
#
#     * **Child-friendly ratings:** TV-Y, TV-Y7, TV-Y7-FV, TV-G
#
#     * **Parental guidance suggested ratings:** TV-PG, PG
#
#     * **Teen and older audience ratings:** TV-14, PG-13
#
#     * **Mature audience ratings:** TV-MA, R, NC-17
#
#     * **Unrated categories:** NR, UR

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 (What are different content available and which dominate the most? )

# %%
# Create a pie chart for Type.
colors = ['red', '#87CEEB'] # #db0000', '	#564d4d'
labels = ['Tv Show', 'Movie']
tv_show = df.type.value_counts()[1]
movie = df.type.value_counts()[0]

fig = go.Figure(data=[go.Pie(labels=labels, values=[tv_show, movie], hole=.6)])
fig.update_layout(
    title_text="Type of content watched on Netflix",title_x=0.5, legend=dict(x=0.9),height=500, width=750,
    # Add annotations in the center of the donut pies.
    annotations=[dict(text='Type of content.', font_size=20, showarrow=False)])
fig.update_traces(marker=dict(colors=colors))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="93b8460a-1354-4f56-9089-3e53852479fa" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93b8460a-1354-4f56-9089-3e53852479fa")) {                    Plotly.newPlot(                        "93b8460a-1354-4f56-9089-3e53852479fa",                        [{"hole":0.6,"labels":["Tv Show","Movie"],"values":[49728,126079],"type":"pie","marker":{"colors":["red","#87CEEB"]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* We choose the Pie chart because it's good for analyzing the distribution of differnt topics present in the feature.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* We can see that the majority of the content on Netflix is movies, which account for around two-thirds of the total content. TV shows make up the remaining one-third of the content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* As the Movie content dominate in Netflix, the OTT platform should focus to produce or acquire the more TV Shows contant as to attract the peoples who loves further one.

# %% [markdown]
# #### Chart - 2 (Is the content address the general subscribers and what's content raing distribution? )

# %%
# Counting the value
counts = df['rating'].value_counts()

# Plotting the bar plot
plt.bar(counts.index, counts)
plt.xlabel('Categories')
plt.ylabel('Count')
plt.title('Bar Plot of Content Rating')

# Measuring the height
for i, count in enumerate(counts):
    plt.text(i, count+1, str(count), ha='center', va='bottom')

# Show the output
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* The bar charts are good ways to visualize the distribution over the categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Highest number of content avaliable on nextflix is rated as <b>Mature</b>.
# >* The <b>Family-Friendly</b> content which is rated as <b>G</b> are less in numbers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* Netflix should focus on increasing the general rated content as it tabs the new categories of subscribers which likes to view only <b>Family-Friendly</b> content.

# %% [markdown]
# #### Chart - 3 (How is the content growth over the year on netflix? )

# %%
# Plot growth of the contents over the years.
tv_show = df[df["type"] == "TV Show"]
movie = df[df["type"] == "Movie"]

col = "year_added"

content_1 = tv_show[col].value_counts().reset_index()
content_1 = content_1.rename(columns = {col : "count", "index" : col})
content_1 = content_1.sort_values(col)

content_2 = movie[col].value_counts().reset_index()
content_2 = content_2.rename(columns = {col : "count", "index" : col})
content_2 = content_2.sort_values(col)

trace1 = go.Scatter(x=content_1[col], y=content_1["count"], name="TV Shows", marker=dict(color="#db0000"))
trace2 = go.Scatter(x=content_2[col], y=content_2["count"], name="Movies", marker=dict(color="#564d4d"))

data = [trace1, trace2]
layout = go.Layout(title="Content added over the years",title_x=0.47, legend=dict(x=0.4, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a8945609-dd3d-4ae4-8537-477b562066b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8945609-dd3d-4ae4-8537-477b562066b7")) {                    Plotly.newPlot(                        "a8945609-dd3d-4ae4-8537-477b562066b7",                        [{"marker":{"color":"#db0000"},"name":"TV Shows","x":[2008,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1,132,125,515,3810,7158,8143,14000,15407,437],"type":"scatter"},{"marker":{"color":"#564d4d"},"name":"Movies","x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[18,30,20,258,36,75,343,1127,4931,18937,28359,36496,33053,2396],"type":"scatter"}],                        {"legend":{"orientation":"h","x":0.4,"y":1.1},"title":{"text":"Content added over the years","x":0.47},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"typ ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* Line charts are useful for visualizing the tread over specified time interval it's help us to understand the pattern in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Growth in the number of movies on Netflix is much higher than tv shows.
# >* From 2015 we can see a noticeable addition in the number of movies and tv shows uploaded by Netflix on its platform.
# >* The highest number of movies and tv shows got added in 2019 and 2020.
# >* The line plot shows very few movies, and tv shows got added in 2021. It is due to very little data collected from the year 2021.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* The content avaliability of movies is more than the tv shows it impacts the segment of the customers who like to enjoy the tv content on OTTs.
#
# >* Increasing the tv shows will definitly get the more houeholds sub.

# %% [markdown]
# #### Chart - 4 (On which months the more content addition take place?)

# %%
# Create dataframe to store manth values and counts.
months_df = pd.DataFrame(df.month_added.value_counts())
months_df.reset_index(inplace=True)
months_df.rename(columns={'index':'month', 'month_added':'count'}, inplace=True)

# %%
# Plotting the bar plots
fig = px.bar(months_df, x="month", y="count", text_auto=True, color='count', color_continuous_scale=['#db0000', '#564d4d'])
fig.update_layout(
    title={
        'text': 'Month wise addition of movies and shows to the platform',
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
        autosize=False,
        width=1000,
        height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="377a0fd7-102a-488f-9118-13077a2c69fc" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("377a0fd7-102a-488f-9118-13077a2c69fc")) {                    Plotly.newPlot(                        "377a0fd7-102a-488f-9118-13077a2c69fc",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>count=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[18895,18532,18239,16297,14166,14072,13806,13446,12958,12492,12039,10865],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":[1,12,10,11,3,9,7,8,4,6,5,2],"xaxis":"x","y":[18895,18532,18239,16297,14166,14072,13806,13446,12958,12492,12039,10865],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","siz ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* The bar plots are useful for analyzing the growth of discrete values in the data sets.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Most of the content is uploaded either by year ending or beginning.
# >* October, November, December, and January are months in which many shows and movies get uploaded to the platform.
# >* It might be due to the long Christmas holiday and winters in the west word.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* Not much specific in this context

# %% [markdown]
# #### Chart - 5 (Which days are more prominent? )

# %%
# Create dataframe to store day values and count.
days_df = pd.DataFrame(df.day_added.value_counts())
days_df.reset_index(inplace=True)
days_df.rename(columns={'index':'day', 'day_added':'count'}, inplace=True)

# %%
fig = px.bar(days_df, x="day", y="count", text_auto=True, color='count', color_continuous_scale=['#db0000', '#564d4d'])
fig.update_layout(
    title={
        'text': 'Which days are more prominent',
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
        autosize=False,
        width=1200,
        height=600)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="56033519-e380-4760-b51e-362566726fd4" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56033519-e380-4760-b51e-362566726fd4")) {                    Plotly.newPlot(                        "56033519-e380-4760-b51e-362566726fd4",                        [{"alignmentgroup":"True","hovertemplate":"day=%{x}<br>count=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[48378,14442,6604,5341,5140,5101,4950,4872,4628,4537,4406,4215,4028,4019,3847,3731,3731,3642,3545,3526,3526,3459,3439,3051,3014,2994,2937,2889,2637,2603,2575],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":[1,15,16,31,5,2,20,8,19,10,30,26,25,7,4,21,6,28,22,14,27,18,23,13,9,12,24,17,11,29,3],"xaxis":"x","y":[48378,14442,6604,5341,5140,5101,4950,4872,4628,4537,4406,4215,4028,4019,3847,3731,3731,3642,3545,3526,3526,3459,3439,3051,3014,2994,2937,2889,2637,2603,2575],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type" ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* We have to analyze the discrete distribution for that purpose we use the bar.

# %% [markdown]
# ##### 2.  What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Most content addition takes place in the beginning of the month or at the middle of the month.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* Not specific in this context

# %% [markdown]
# #### Chart - 6 (How mutch content is produced by different countries?)

# %%
# Import dataset containing Contries and their codes.
link = 'https://raw.githubusercontent.com/ashish-mali/Netflix-Movies-And-TV-Shows-Clustering/main/Data_Files/countries_code_updated.csv'

country_code_df = pd.read_csv(link, encoding= 'unicode_escape', usecols=['Country', 'Code'])

# %%
# Create a dict to store counts of each country appearing in our dataset.
countries = ", ".join(df['Country']).split(", ")
countries_dict = dict(Counter(countries))
countries_dict = dict((key, value) for key, value in countries_dict.items())

# %%
# Map the country code dataset with countries dict.
country_code_df['Count'] = country_code_df['Country'].map(countries_dict)

# %%
# Country codes df with country counts.
country_code_df.head()
# Out:
#          Country Code  Count
# 0         Brazil  BRA   1650
# 1         Mexico  MEX   3551
# 2      Singapore  SGP    689
# 3  United States  USA  52126
# 4         Turkey  TUR   2617

# %%
# Create Geo plot to see which country produces more content.

# Define data
data = dict(type='choropleth', 
            locations = country_code_df['Code'], 
            z = country_code_df['Count'], 
            text = country_code_df['Code'],
            marker = dict(line = dict (color = 'grey',width = 0.5)),
            # colorbar = dict(autotick = True, title = '')
            )

# Define layout.
layout = dict(title = 'Country-wise Content Production', title_x=0.5,height=700, width=1500,
              geo = dict( projection = {'type':'times'},
                         showlakes = False,
                         showcoastlines = False,
                         showframe = False, 
                         showocean = False,
                         showland = False,
                         fitbounds = 'locations',
                         ))

# Plot it.
country_plot = go.Figure(data = [data], 
              layout = layout
              )

#iplot(country_plot)
country_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1ac94d3d-f7cb-4ac4-877a-bfebc903ff77" class="plotly-graph-div" style="height:700px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ac94d3d-f7cb-4ac4-877a-bfebc903ff77")) {                    Plotly.newPlot(                        "1ac94d3d-f7cb-4ac4-877a-bfebc903ff77",                        [{"locations":["BRA","MEX","SGP","USA","TUR","EGY","IND","POL","THA","NGA","XXX","NOR","ISL","GBR","JPN","KOR","ITA","CAN","IDN","ROU","ESP","ZAF","FRA","PRT","HKG","CHN","DEU","ARG","SRB","DNK","KEN","NZL","PAK","AUS","TWN","NLD","PHL","ARE","IRN","BEL","ISR","URY","BGR","CHL","RUS","MUS","LBN","COL","DZA","RUS","SWE","MYS","IRL","LUX","FIN","AUT","PER","SEN","CHE","GHA","SAU","ARM","JOR","MNG","NAM","QAT","VNM","SYR","KWT","MLT","CZE","BHS","LKA","CYM","BGD","USA","ZWE","HUN","LVA","LIE","VEN","MAR","KHM","ALB","CUB","NIC","GRC","KHM","HRV","GTM","DEU","POL","SVN","DOM","NPL","WSM","AZE","BMU","ECU","GEO","BWA","PRI","IRQ","VAT","AGO","UKR","JAM","BLR","CYP","KAZ","MWI","SVK","LTU","AFG","PRY","SOM","SDN","PAN","GBR","UGA","DEU","MNE"],"marker":{"line":{"color":"grey","width":0.5}},"text":["BRA","MEX","SGP","USA","TUR","EGY","IND","POL","THA","NGA","XXX","NOR","ISL","GBR","JPN","KOR","ITA","CAN","IDN","ROU","ESP","ZAF","FRA","PRT","HKG","CHN","DEU","ARG","SRB","DNK","KEN","NZL","PAK","AUS","TWN","NLD","PHL","ARE","IRN","BEL","ISR","URY","BGR","CHL","RUS","MUS","LBN","COL","DZA","RUS","SWE","MYS","IRL","LUX","FIN","AUT","PER","SEN","CHE","GHA","SAU","ARM","JOR","MNG","NAM","QAT","VNM","SYR","KWT","MLT","CZE","BHS","LKA","CYM","BGD","USA","ZWE","HUN","LVA","LIE","VEN","MAR","KHM","ALB","CUB","NIC","GRC","KHM","HRV","GTM","DEU","POL","SVN","DOM","NPL","WSM","AZE","BMU","ECU","GEO","BWA","PRI","IRQ","VAT","AGO","UKR","JAM","BLR","CYP","KAZ","MWI","SVK","LTU","AFG","PRY","SOM","SDN","PAN","GBR","UGA","DEU","MNE"],"z":[1650,3551,689,52126,2617,2208,21296,834,1687,1687,5944,660,177,11348,7707,4623,1438,7050,1799,239,4991,1185,7317,126,2238,3060,3881,1578,107,910,136,431,535,2341,2008,686,1726,686,109,1964,419,177,163,579,369,20,596,1359,53,132,843,501,969,236,181,174,139,52,348,93,201,2,169,2,16,257,66,24,162,40,313,6,2,42,372,1,42,148,22,27,7,89,70,8,18,1,125,26,71,16,91,27,50,18,48,2,33,12,12,56,2,27,6,3,32,52,27,6,10,1,24,20,26,2,52,10,10,2,2,1,30,20],"type":"choropleth"}],                        {"geo":{"fitbounds":"locations","projection":{"type":"times"},"showcoastlines":false,"showframe":false,"showlakes":false,"showland":false,"showocean":false},"height":700,"title":{"text":"Country-wise Content Production","x":0.5},"width":1500,"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"], ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* In this instance, the geo chart is helpful for better comprehending the distribution of Netflix content around the world.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Most of the content is produced by USA
# >* Except, few middle eastren countries, south african countries we see overall presence of the netflix.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# > Not much specific in this context.

# %% [markdown]
# #### Chart - 7 (Which country's content are more on netflix?)

# %%
# Top 10 countries with the highest number movies / TV shows in the dataset
plt.figure(figsize=(10,5))
df[~(df['Country']=='Unknown')].Country.value_counts().nlargest(10).plot(kind='barh', color='#db0000')
plt.title(' Top 10 countries with the highest number of shows')
# Out:
# Text(0.5, 1.0, ' Top 10 countries with the highest number of shows')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* Horizontal bar chart are useful for finding out the largest to smallest relationship.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Most of the content are from USA followed by India and United Kingdom.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* Not much specific in this context

# %% [markdown]
# #### Chart - 8 (What are the most popular content genres?)

# %%
# Top 10 genres 
plt.figure(figsize=(10,5))
df.Genre.value_counts().nlargest(10).plot(kind='barh', color='#db0000')
plt.title('Top 10 genres')
# Out:
# Text(0.5, 1.0, 'Top 10 genres')

# %%
['Drams', 'International Movies', 'Comedies', 'International TV Shows', 'Action & Adventure']
# Out:
# ['Drams',
#  'International Movies',
#  'Comedies',
#  'International TV Shows',
#  'Action & Adventure']

# %% [markdown]
# >* let's analyze the share volume in percentage.

# %%
# Share of top 3 genres
print(round((df.Genre.value_counts().nlargest(3).sum()/len(df)*100), 2), '%')
# Out:
# 39.07 %

# %%
# Share of top 10 genres
print(round((df.Genre.value_counts().nlargest(10).sum()/len(df)*100), 2), '%')
# Out:
# 71.99 %

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* Horizontal bar chart are useful for finding out the largest to smallest relationship.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Most popular genre are <b>Drams</b> followed by <b>International Movies</b>.
#
# >* The share volume of top three are accounted to <b>39%</b>

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# > Not much specific in this context

# %% [markdown]
# #### Chart - 9 (Whcih year the most content was released?)

# %%
# Put the data into bins.
release_yr_bin = pd.cut(df.release_year, [1924, 1999, 2010, 2021])
release_yr_bin.value_counts()
release_yr_bin = pd.DataFrame(release_yr_bin.value_counts()).reset_index()
release_yr_bin.rename(columns={'index':'year_interval', 'release_year':'count'}, inplace=True)
release_yr_bin['year_interval'] = release_yr_bin['year_interval'].astype('string')
release_yr_bin
# Out:
#   year_interval   count
# 0  (2010, 2021]  139069
# 1  (1999, 2010]   25513
# 2  (1924, 1999]   11225

# %%
# Plot it.
fig = px.pie(release_yr_bin, values='count', names='year_interval', color_discrete_sequence=px.colors.sequential.Aggrnyl, title='When was most content released.',height=500, width=500)

# Show the output
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e516590e-2424-45d0-a06e-ecec11b45803" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e516590e-2424-45d0-a06e-ecec11b45803")) {                    Plotly.newPlot(                        "e516590e-2424-45d0-a06e-ecec11b45803",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"year_interval=%{label}<br>count=%{value}<extra></extra>","labels":["(2010, 2021]","(1999, 2010]","(1924, 1999]"],"legendgroup":"","name":"","showlegend":true,"values":[139069,25513,11225],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"patte ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* Pie charts are best suitable for analyzing the contribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Most the content is added during <b>2010</b> to <b>2021</b>.
#
# >* It is due to expantion of netflix in other countries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* Not much specific in this context

# %% [markdown]
# #### Chart - 10 (How is the distribution of the duration of movies?)

# %%
# length of movie analysis
plt.figure(figsize=(10,5))
sns.histplot(x='duration',data=df[df['type']=='Movie'])
plt.title('Movie duration distribution')
# Out:
# Text(0.5, 1.0, 'Movie duration distribution')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* To analyze the distribution histplot is the good choise.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* We see some what normally distributed data points when it comes to duration
#
# >* Most of the movies are between 90 to 120 mins.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* Not much specific in this context

# %% [markdown]
# #### Chart - 11 (what is the impact of movie time over the years?)

# %%
# Average movie length over the years
plt.figure(figsize=(10,5))
df[df['type']=='Movie'].groupby('release_year')['duration'].mean().plot(kind='line')
plt.title('Average movie length over the years')
plt.ylabel('Length of movie in minutes')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* line plot are good for the analyzing the trands over the year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Netflix has several movies on its site, including those that were released in way back 1942.
# >* As per the plot, movies made in the 1940s had a fairly short duration on average.
# >* On average, movies made in the 1960s have the longest movie length.
# >* The average length of a movie has been continuously decreasing since the 2000s.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* Not mutch specific in this context

# %% [markdown]
# #### Chart - 12 (What is the Rate of Movies/TV Shows adding per day, month and year on Netflix?)

# %%
# Chart - 11 visualization code
interval= ['year_added','month_added','day_added']
plt.figure(figsize=(20,5))
for i,j in enumerate(interval):
  plt.subplot(1,3,i+1)
  df_interval = df.groupby([j,'type']).agg({'title':'nunique'}).reset_index().sort_values(by=[j],ascending=False)
  sns.lineplot(x = j,y='title', data = df_interval, palette = 'husl', hue = df_interval['type'], marker = 'o')
  plt.grid(linestyle='--', linewidth=0.3)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* This graph shows us the variation of Movies/TV Shows added in month, day, Year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Here we can see that during covid times in the year 2019 the movie addition increased rapidly and reaches its peak.
#
# >* The **movie/tv shows added in Netflix is maximum in the weekends**, we can see peak in the interval of 6th day.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* Producers should target the audience in weekends and during festival month for more revenue.

# %% [markdown]
# #### Chart - 13 (Which words are more prominant in movie/tv titles?)

# %%
# Create a string to store all the words.
comment_words = ''

# Remove the stopwords.
stopwords = set(STOPWORDS)
 
# iterate through the column.
for val in df.title.values:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 1000, height = 500,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10,
                max_words = 1000,
                colormap = 'gist_heat_r').generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.title('Most used words in title', fontsize = 15, pad=25)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* For analyzing the overall frequency of the words in any context words cloude are best options

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Most frequent words are :
#     - prophet
#     - kahlil
#     - gibran
#     - holidays
#     - power
#     - rangers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* By suggesting the most frequent words, we can reduce the search effort of customers and improvies customer satification.

# %% [markdown]
# #### Chart - 14  (Which words are more prominant in description?)

# %%
# Create a string to store all the words.
comment_words = ''

# Remove the stopwords.
stopwords = set(STOPWORDS)
 
# iterate through the column.
for val in df.description.values:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 1000, height = 500,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10,
                max_words = 1000,
                colormap = 'gist_heat_r').generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.title('Most used words in description', fontsize = 15, pad=25)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* For analyzing the overall frequency of the words in any context words cloude are best options

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* Most frequent words in description are :
#     - life
#     - help
#     - love
#     - find
#     - live
#     - high
#     - school
#     - save
#     - world

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >* Not much specific in this context

# %% [markdown]
# #### Chart - 15  (What is the Distribution of Content Rating in each highest content creating countries?)

# %%
# Correlation Heatmap visualization code
# Preparing data for heatmap
df['count'] = 1
data = df.groupby('Country')[['Country','count']].sum().sort_values(by='count',ascending=False).reset_index()[:10]
data = data['Country']
df_heatmap = df.loc[df['Country'].isin(data)]
df_heatmap = pd.crosstab(df_heatmap['Country'],df_heatmap['rating'],normalize = "index").T

# Plotting the heatmap
fig, ax = plt.subplots(1, 1, figsize=(10, 8))

# Defining order of representation
country_order = ['United States', 'India', 'United Kingdom', 'Japan', 'France', 'Canada', 'Spain', 'South Korea', 'Germany']
rating_order = ['Mature', 'Teen and older', 'Parental guidance', 'Unrated', 'Child-friendly']

# calling and plotting heatmap
sns.heatmap(df_heatmap.loc[rating_order,country_order], cmap='Set2', square=True,linewidth=2.5,cbar=False,annot=True,fmt='1.0%',vmax=.6,vmin=0.05,ax=ax,annot_kws={"fontsize":12})
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >* HeatMap are the best way to visualize the relationship between two variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >* For all the developed country's <b>Mature</b> content rating dominates the most.
#
# >* In the context of India <b>Teen and older</b> content rating dominates the most.
#
# >* <b>Spain</b> has the highest <b>Mature</b> content rating avaliable.
#
# >* The highest number of <b>Child-friendly</b> content rating avaliable in <b>Canada</b>.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# >* <b>Statement-01:-</b> The average duration of movies is 90 minutes.
#
# >* <b>Statement-02:-</b> The proportion of TV shows with a rating of TV-MA is greater than 50%.
#
# >* <b>Statement-03:-</b> : There is a significant difference in the release year between movies and TV shows.

# %% [markdown]
# ### Hypothetical Statement - 1
#
# #### The average duration of movies is 90 minutes.

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# >* <b>Null Hypothesis ($H_o$) :</b> $μ$ $=$ $90$
#
# >* <b>Alternate Hypothesis ($H_a$) :</b> $μ$ ${≠}$ $90$
#
# > Where
#
# >>* $μ$ $=$ Average movies duration.
#
# >>* Test Type :-  One-Sample T- Test
#
# >>* Singificance Level = 0.05

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Considering only movies
movies_duration = df[df['type'] == 'Movie']['duration']

# %%
# Performing Test
t_statistic, p_value = stats.ttest_1samp(movies_duration, 90)

# %%
# Print the test results
print("test statistic score:", t_statistic)
print("P-value:", p_value)
# Out:
# test statistic score: 239.84303852682135
# P-value: 0.0

# %%
# taking alpha value
alpha = 0.05

# Conditional Check for final output
if p_value < alpha:
    print("Reject null hypothesis. The average duration of movies is not 90 minutes.")
else:
    print("Fail to reject null hypothesis. The average duration of movies is 90 minutes.")
# Out:
# Reject null hypothesis. The average duration of movies is not 90 minutes.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# >* We use one sample t-test to obtain the p-value.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# >* We use a t-test to compare the mean duration of movies to a hypothesized value (in this case, 90 minutes) when the population standard deviation is unknown. The t-test is a statistical test that allows us to determine whether the difference between the sample mean and the hypothesized value is statistically significant, given the sample size and the standard error of the sample mean.
#
# >* In most cases, we do not know the population standard deviation, and we must estimate it using the sample standard deviation. This introduces additional uncertainty into the calculation of the test statistic, and the t-test corrects for this by using a modified distribution (the t-distribution) that takes into account the sample size and the sample standard deviation.
#
# >* Therefore, we use a t-test to compare the mean duration of movies to a hypothesized value of 90 minutes because we do not know the population standard deviation, and we need to estimate it using the sample standard deviation.

# %% [markdown]
# ### Hypothetical Statement - 2
#
# #### The proportion of TV shows with a rating of TV-MA is greater than 50%.

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# >* <b>Null Hypothesis ($H_o$) :</b> Prop. = 50%
#
# >* <b>Alternate Hypothesis ($H_a$) :</b> Prop. ${≠}$  50%
#
# > Where
#
# >>* Prop. $=$ Proportion of TV Shows.
#
# >>* Test Type :-  One-sample proportion test
#
# >>* Singificance Level = 0.05

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Getting the tv-shows which having the rating of TV-MA
tvshows_rating = df[df['type'] == 'TV Show']['rating']

# Taking sum
num_tvshows_TVMA = sum(tvshows_rating == 'TV-MA')

# Counting the length
num_tvshows = len(tvshows_rating)

# %%
# Taking p-hat at 0.5
p_hat = 0.5

# Performing staststical test
z_statistic, p_value = proportions_ztest(num_tvshows_TVMA, num_tvshows, p_hat)

# %%
# Print the test results
print("Z-Statistic score:", z_statistic)
print("P-value:", p_value)
# Out:
# Z-Statistic score: -inf
# P-value: 0.0

# %%
# taking alpha value
alpha = 0.05

# Conditional Check for final output
if p_value < alpha:
    print("Reject null hypothesis. The proportion of TV shows with a rating of TV-MA is greater than 50%.")
else:
    print("Fail to reject null hypothesis. The proportion of TV shows with a rating of TV-MA is equal to 50%.")
# Out:
# Reject null hypothesis. The proportion of TV shows with a rating of TV-MA is greater than 50%.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# >* We use one-sample proportion test for testing the hypothesis.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# >* We used a one-sample proportion test because we are interested in testing a hypothesis about a proportion, specifically the proportion of TV shows with a rating of TV-MA. This type of test is appropriate when we have a sample proportion and want to compare it to a hypothesized value to see if it is significantly different. In our case, the null hypothesis assumes that the proportion of TV shows with a rating of TV-MA is equal to 50%, and we want to test if there is evidence to support the alternative hypothesis that the proportion is greater than 50%.
#
# >* The one-sample proportion test is commonly used for this type of scenario, and it allows us to calculate the p-value, which is the probability of observing a sample proportion as extreme or more extreme than what we observed, assuming that the null hypothesis is true. If the p-value is smaller than the significance level, typically set at 0.05, we reject the null hypothesis in favor of the alternative hypothesis.

# %% [markdown]
# ### Hypothetical Statement - 3
#
# #### There is a significant difference in the release year between movies and TV shows.

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# >* <b>Null Hypothesis ($H_o$) :</b> $\mu_{movie} = \mu_{TV}$
#
# >* <b>Alternate Hypothesis ($H_a$) :</b>  $\mu_{movie} \neq \mu_{TV}$
#
# > Where
#
# >>* $\mu_{movie}$. $=$ Mean for released year for movie
#
# >>* $\mu_{TV}$. $=$ Mean for released year for TV
#
# >>* Test Type :-  Two-sample t-test
#
# >>* Singificance Level = 0.05

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Getting the movies and their respective release year
movies_release_year = df[df['type'] == 'Movie']['release_year']

# Getting the tv-shows and their respective release year
tvshows_release_year = df[df['type'] == 'TV Show']['release_year']

# %%
# Performing the t-stat test
t_statistic, p_value = stats.ttest_ind(movies_release_year, tvshows_release_year)

# %%
# Print the test results
print("T-Statistic score:", t_statistic)
print("P-value:", p_value)
# Out:
# T-Statistic score: -95.09865025877725
# P-value: 0.0

# %%
# taking alpha value
alpha = 0.05

# Conditional Check for final output
if p_value < alpha:
    print("Reject null hypothesis. There is a significant difference in the release year between movies and TV shows.")
else:
    print("Fail to reject null hypothesis. There is no significant difference in the release year between movies and TV shows.")
# Out:
# Reject null hypothesis. There is a significant difference in the release year between movies and TV shows.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# >* We can use a two-sample t-test to test this hypothesis

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# >* We used a two-sample t-test to test this hypothesis because we have two independent groups (movies and TV shows) and we want to compare the means of the release year variable between these two groups.
#
# >* The two-sample t-test is appropriate when we have two independent groups and want to determine whether the means of a continuous variable are significantly different between the two groups. In this case, we want to determine whether the mean release year for movies is significantly different from the mean release year for TV shows.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
# As we already revomed the null value in data wrangling let's have a quck look of it.
pd.DataFrame(df.isnull().sum(), columns=['Null_Value_Count'])
# Out:
#               Null_Value_Count
# title                        0
# Actors                       0
# Directors                    0
# Genre                        0
# Country                      0
# type                         0
# release_year                 0
# rating                       0
# duration                     0
# description                  0
# day_added                    0
# month_added                  0
# year_added                   0
# count                        0

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# >* For some feature we such as 'Directors', 'Actors' and 'Country' we impute the null values with the string as "Unknown"
#
# >* And for the remaining features which does have the null value we decided to droop tham as they does't share the significant percentage and don't have an impact on information loss.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Let's create the function which create the boxplot for given DataFrame.
def plot_box_plots(df):

    # Doc. sting
    '''
    This function creates the boxplot for each numerical features for given DataFrame 
    '''
    # Selectin only numerical features
    numerical_columns = df.select_dtypes(include=['float', 'int']).columns

    # Define the subplots
    fig, ax = plt.subplots(1, len(numerical_columns), figsize=(20, 5))

    # looping & boxplot creation
    for i, column in enumerate(numerical_columns):
        ax[i].boxplot(df[column])
        ax[i].set_title(f'Box Plot of {column}', fontsize=14, fontweight='bold')
    plt.tight_layout()
    
    # show the plots
    plt.show()

# %%
# Fucntion calling
plot_box_plots(df)

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# >* Although we have some of the anomalies in continous feature but we will not treat by considering outliers as some of the Movies/TV Shows has released or added early on Netflix.

# %% [markdown]
# ### 3. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %%
# Here we are taking the copied dataframe as the data having more number of observations resulted in ram exhaustion.
df.shape, df_new.shape
# Out:
# ((175807, 14), (7770, 11))

# %% [markdown]
# #### 1. Binning of Rating Feature for Selected Data Frame.

# %%
# Binning of rating in new dataframe
df_new['rating'].replace(rating_categories, inplace = True)

# Checking sample after binning
df_new.sample(2)
# Out:
#             type                                     title       director  \
# show_id
# s3148    TV Show          Jenni Rivera: Mariposa de Barrio        Unknown
# s4252      Movie  Mr. Gaga: A True Story of Love and Dance  Tomer Heymann
#
#                                                       cast  \
# show_id
# s3148    AngÃ©lica Celaya, Gabriel Porras, Rosalinda Ro...
# s4252                                         Ohad Naharin
#
#                                       country       date_added  release_year  \
# show_id
# s3148                           United States  January 1, 2021          2017
# s4252    Israel, Sweden, Germany, Netherlands    June 15, 2017          2015
#
#                  rating  duration                             listed_in  \
# show_id
# s3148            Mature  1 Season  Spanish-Language TV Shows, TV Dramas
# s4252    Teen and older   102 min   Documentaries, International Movies
#
#                                                description
# show_id
# s3148    This drama follows Mexican-American singer Jen...
# s4252    World-renowned choreographer Ohad Naharin is p...

# %% [markdown]
# #### 2. Expand Contraction

# %% [markdown]
# >* In textual data preprocessing, Expand contraction refers to the process of expanding shortened words or contractions into their full forms. For example, converting "don't" to "do not", "can't" to "cannot", "I'm" to "I am" and so on.
#
# >* Expanding contractions can help improve the accuracy of text analysis since the meaning of the full form of a word or phrase may be different from its shortened form, and the full form may be recognized as a separate word by text analysis tools.

# %%
# apply expansion and contraction on each row
df_new['description'] = df_new['description'].apply(lambda x: contractions.fix(x))

# %%
# Checking sample after expantion
df_new.sample(5)
# Out:
#             type                          title              director  \
# show_id
# s7427      Movie  Vir Das: Abroad Understanding          Marcus Raboy
# s2286    TV Show             Friday Night Tykes               Unknown
# s5814      Movie                         Stereo  Maximilian Erlenwein
# s2902      Movie                    I Am Sun Mu         Adam SjÃ¶berg
# s3675      Movie       Little Singham: Mahabali         Prakash Satam
#
#                                                       cast  \
# show_id
# s7427                                              Vir Das
# s2286                                              Unknown
# s5814    JÃ¼rgen Vogel, Moritz Bleibtreu, Petra Schmidt...
# s2902                                              Unknown
# s3675    Saumya Daan, Sonal Kaushal, Anamaya Verma, Gan...
#
#                                    country         date_added  release_year  \
# show_id
# s7427                        United States     April 25, 2017          2017
# s2286                        United States   January 17, 2018          2017
# s5814                              Germany   January 15, 2017          2014
# s2902    China, South Korea, United States   February 1, 2017          2015
# s3675                              Unknown  November 27, 2019          2019
#
#                     rating   duration                            listed_in  \
# show_id
# s7427               Mature     66 min                      Stand-Up Comedy
# s2286    Parental guidance  4 Seasons               Docuseries, Reality TV
# s5814               Mature     91 min      International Movies, Thrillers
# s2902              Unrated     88 min  Documentaries, International Movies
# s3675       Child-friendly     69 min   Children & Family Movies, Comedies
#
#                                                description
# show_id
# s7427    Comedian Vir Das tackles nationalism, globalis...
# s2286    This docuseries dives into the cutthroat world...
# s5814    Erik's peaceful rural family life is shaken by...
# s2902    A North Korean propagandist who escaped to Seo...
# s3675    In a journey back in time to the ancient city ...

# %% [markdown]
# #### 3. Clustering Attributes

# %% [markdown]
# We will cluster the movie/shows on Netflix based on the following attributes:
#
# >* Director
# >* Cast
# >* Country
# >* Rating
# >* Listed in (genres)
# >* Description
# >* type

# %%
# Creating new feature content_detail with the help of other textual attributes
df_new["content_detail"]= df_new["cast"]+" "+df_new["director"]+" "+df_new["listed_in"]+" "+df_new["type"]+" "+df_new["rating"]+" "+df_new["country"]+" "+df_new["description"]

#checking the manipulation
df_new.head(5)
# Out:
#             type  title           director  \
# show_id
# s1       TV Show     3%            Unknown
# s2         Movie   7:19  Jorge Michel Grau
# s3         Movie  23:59       Gilbert Chan
# s4         Movie      9        Shane Acker
# s5         Movie     21     Robert Luketic
#
#                                                       cast        country  \
# show_id
# s1       JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# s2       DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#                 date_added  release_year          rating   duration  \
# show_id
# s1         August 14, 2020          2020          Mature  4 Seasons
# s2       December 23, 2016          2016          Mature     93 min
# s3       December 20, 2018          2011          Mature     78 min
# s4       November 16, 2017          2009  Teen and older     80 min
# s5         January 1, 2020          2008  Teen and older    123 min
#
#                                                  listed_in  \
# show_id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# s2                            Dramas, International Movies
# s3                     Horror Movies, International Movies
# s4       Action & Adventure, Independent Movies, Sci-Fi...
# s5                                                  Dramas
#
#                                                description  \
# show_id
# s1       In a future where the elite inhabit an island ...
# s2       After a devastating earthquake hits Mexico Cit...
# s3       When an army recruit is found dead, his fellow...
# s4       In a postapocalyptic world, rag-doll robots hi...
# s5       A brilliant group of students become card-coun...
#
#                                             content_detail
# show_id
# s1       JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...
# s2       DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...

# %% [markdown]
# #### 4. Lower Casing

# %% [markdown]
# ><b>Lowercasing Words</b> is the process of converting all the words in a text to lowercase. This is a common pre-processing step in NLP tasks, as it can be useful for a few reasons:
#
# >>* <b>Case differences can be ignored:<br></b> By lowercasing the words, you can treat words with different capitalization as the same word, which can be useful in tasks such as information retrieval or text classification where case differences are not important.
#
# >>* <b>Vocabulary size is reduced:</b><br> Lowercasing the words can also reduce the size of the vocabulary, which can make it easier to work with larger texts or texts in languages with a high number of inflected forms.

# %%
# Lower Casing
df_new['content_detail']= df_new['content_detail'].str.lower()

# %%
# Checking the manipulation
df_new.iloc[99,]['content_detail']
# Out:
# "aamir khan, kareena kapoor, madhavan, sharman joshi, omi vaidya, boman irani, mona singh, javed jaffrey rajkumar hirani comedies, dramas, international movies movie teen and older india while attending one of india's premier colleges, three miserable engineering students and best friends struggle to beat the school's draconian system."

# %% [markdown]
# #### 5. Removing Punctuations

# %% [markdown]
# >* In natural language processing, removing punctuation refers to the process of eliminating all the punctuations from the text data. Punctuation includes symbols such as periods, commas, semicolons, question marks, exclamation points, etc.
#
# >* Removing punctuations is an essential step in data preprocessing because punctuation does not add any meaningful information to the text data, and it can interfere with the machine learning models' ability to understand the text's meaning. Moreover, removing punctuations reduces the dimensionality of the text data and makes it easier to tokenize the text into individual words.
#
# >* There are different ways to remove punctuations from text data in data preprocessing. One of the simplest ways is to use regular expressions to match and remove all the punctuations from the text. Another way is to use built-in functions or libraries in programming languages like Python, which have functions to remove punctuations from text data.
#
# >* We use the `str.maketrans()` function to create a translation table that maps each punctuation character in `string.punctuation` to `None`. We then use the `translate()` function to remove all punctuation from the sentence.

# %%
# Remove Punctuations
# function to remove punctuations
def remove_punctuations(text):
    '''This function is used to remove the punctuations from the given sentence'''

    # replacing the punctuations with no space, which in effect deletes the punctuation marks.
    translator = str.maketrans('', '', string.punctuation)
    
    # return the text stripped off punctuation marks
    return text.translate(translator)

# %%
# Removing Punctuations from the content_detail using lambda function
df_new['content_detail']= df_new['content_detail'].apply(remove_punctuations)

# %%
# Checking the observation after manipulation
df_new.iloc[99,]['content_detail']
# Out:
# 'aamir khan kareena kapoor madhavan sharman joshi omi vaidya boman irani mona singh javed jaffrey rajkumar hirani comedies dramas international movies movie teen and older india while attending one of indias premier colleges three miserable engineering students and best friends struggle to beat the schools draconian system'

# %% [markdown]
# #### 6. Removing URLs & Removing words and digits contain digits.

# %% [markdown]
# <b>What we means when we say removing urls and words and digit contain digits.?</b>
#
# >* URLs: URLs are web addresses that often appear in text data. They do not contribute to the semantic meaning of the text and may even contain sensitive information. Therefore, it is important to remove URLs from text data during preprocessing to avoid the influence of these irrelevant or even harmful elements on the analysis.
#
# >* Words and digits containing digits: In text data, there may be words or numbers that contain digits, such as phone numbers or product codes. These elements do not contribute to the meaning of the text and may cause issues in the analysis if not removed, such as interfering with word frequency analysis or natural language processing models.
#
# <b>What are the advantages of doing the above?</b>
#
# >* <b>Dimensionality reduction:</b> <br>Removing URLs, words, and digits containing digits can also reduce the dimensionality of the text data, making it easier to process and analyze the data. This simplification can speed up data processing and analysis, and improve the performance of natural language processing models.
#
# >* <b>Better model performance:</b> <br>By removing URLs, words and digits containing digits, we can improve the accuracy and efficiency of natural language processing models. By removing irrelevant data, the models are better able to identify and analyze the relevant features and patterns in the text.

# %%
# Remove URLs & Remove words and digits contain digits
# Let's create the function which take care of the requirement.
def remove_url_and_numbers(text):
    '''This function is used to remove the URL's and Numbers from the given sentence'''
    
    # Replacing the URL's with no space
    url_number_pattern = re.compile(r'https?://\S+|www\.\S+')
    text= re.sub(url_number_pattern,'', text)

    # Replacing the digits with one space
    text = re.sub('[^a-zA-Z]', ' ', text)

    # return the text stripped off URL's and Numbers
    return text

# %%
# Remove URLs & Remove words and digits contain digits using lambda function
df_new['content_detail']= df_new['content_detail'].apply(remove_url_and_numbers)

# %%
# Checking the observation after manipulation
df_new.iloc[1,]['content_detail']
# Out:
# 'demi  n bichir h  ctor bonilla oscar serrano azalia ortiz octavio michel carmen beato jorge michel grau dramas international movies movie mature mexico after a devastating earthquake hits mexico city trapped survivors from all walks of life wait to be rescued while trying desperately to stay alive'

# %% [markdown]
# #### 7. Removing Stopwords & Removing White spaces

# %% [markdown]
# <b>How it helps?</b>
#
# >* <b>Removing Stopwords:</b> <br> Stopwords are commonly used words that do not carry much meaning, such as "the", "and", "a", "an", "in", "of", etc. Removing these words from text data can help to reduce the size of the data, improve the accuracy of natural language processing models, and speed up the processing of the data. This is because stopwords can interfere with the analysis by diluting the importance of the more meaningful words in the text. Removing stopwords can be accomplished using libraries such as `NLTK`, `spaCy`, or `scikit-learn` in Python.
#
# >* <b>Removing White Spaces:</b> <br>White spaces, such as tabs, spaces, and newlines, are non-printable characters that can be found in text data. Removing white spaces from text data is important because they do not contribute to the meaning of the text and can interfere with the analysis. For example, white spaces can make it difficult to tokenize text data, which is necessary for many natural language processing tasks. Removing white spaces can be done using simple string manipulation techniques, such as using the `strip()` function in Python. For this project we use `re` module form the `string` package.

# %%
# Remove Stopwords
# Let's create the function which take care of the requirement.
def remove_stopwords_and_whitespaces(text):
    '''This function is used for removing the stopwords from the given sentence'''

    text = [word for word in text.split() if not word in stopwords.words('english')]

    # joining the list of words with space separator
    text=  " ".join(text)
    
    # removing whitespace
    text = re.sub(r'\s+', ' ', text)

    # return the manipulated string
    return text

# %%
# Remove White spaces using the lambda function
df_new['content_detail']= df_new['content_detail'].apply(remove_stopwords_and_whitespaces)

# %%
# Checking the observation after manipulation
df_new.iloc[99,]['content_detail']
# Out:
# 'aamir khan kareena kapoor madhavan sharman joshi omi vaidya boman irani mona singh javed jaffrey rajkumar hirani comedies dramas international movies movie teen older india attending one indias premier colleges three miserable engineering students best friends struggle beat schools draconian system'

# %% [markdown]
# #### 8. Rephrase Text

# %% [markdown]
# > Rephrasing text refers to the process of replacing certain words or phrases in a sentence with their synonyms or alternative expressions that convey the same meaning. Rephrasing text is often used in textual data preprocessing to improve the quality of the data, make it more understandable, and reduce ambiguity.
#
# > There are several reasons why rephrasing text is important in textual data preprocessing:
#
# >>* <b>Synonyms:</b><br> Replacing words with their synonyms can help to reduce word redundancy, making the text more concise and easier to read. This can also improve the accuracy of natural language processing models, as it ensures that different variations of a word are treated as the same thing.
#
# >>* <b>Language Simplification:</b><br> Rephrasing text can help to simplify complex or technical language, making it more accessible to a wider audience. This is particularly important for natural language processing tasks that involve user-generated content, such as customer reviews or social media posts.
#
# >>* <b>Disambiguation:</b><br> Rephrasing text can help to disambiguate sentences that are unclear or ambiguous. By replacing certain words or phrases with alternative expressions that convey the same meaning, the text can become more clear and less prone to misinterpretation.

# %%
# Rephrase Text
# Let's create the function which take care of the requirement.
def rephrase_text(text):
    """
    Rephrase text by replacing certain words with their synonyms.
    """

    # Tokenize the text
    words = nltk.word_tokenize(text)

    # Loop over each word and replace it with a synonym if available
    for i in range(len(words)):
        # Get the synsets (sets of synonyms) for the current word
        synsets = wordnet.synsets(words[i])

        # If there are synsets, replace the current word with a random synonym from the synset
        if synsets:
            synset = synsets[0] # Use the first synset
            synonyms = synset.lemma_names() # Get the synonyms for the synset
            if len(synonyms) > 1:
                new_word = synonyms[1] # Use the second synonym (arbitrarily chosen)
                words[i] = new_word

    # Join the words back into a string and return it
    rephrased_text = ' '.join(words)
    return rephrased_text

# %%
# Let's Rephrase Text by applying the lambda function
df_new['content_detail']= df_new['content_detail'].apply(rephrase_text)

# %%
# Checking the observation after manipulation
df_new.iloc[99,]['content_detail']
# Out:
# 'aamir khan kareena kapoor madhavan sharman joshi omi vaidya boman Iranian Anglesey_Island singh javed jaffrey rajkumar hirani comedies drama international film film stripling elderly Republic_of_India attending 1 Republic_of_India PM colleges 3 suffering engineering pupil best friends battle round schools draconian system'

# %% [markdown]
# #### 9. Tokenization

# %% [markdown]
# >* Tokenization is the process of splitting a text into smaller units called tokens. In natural language processing (NLP), tokenization is an important step in textual data preprocessing, as it allows us to transform unstructured text data into structured data that can be analyzed by computers.
#
# >* The tokens can be individual words, phrases, or even sentences, depending on the specific requirements of the NLP task. There are different approaches to tokenization, including rule-based methods that rely on specific patterns or characters to identify the tokens, and machine learning-based methods that use statistical models to learn the optimal way to tokenize the text.

# %%
# Tokenization
df_new['pos_tags']= df_new['content_detail'].apply(nltk.word_tokenize)

# %%
# Checking the observation after manipulation
df_new.iloc[99,]['pos_tags']
# Out:
# ['aamir',
#  'khan',
#  'kareena',
#  'kapoor',
#  'madhavan',
#  'sharman',
#  'joshi',
#  'omi',
#  'vaidya',
#  'boman',
#  'Iranian',
#  'Anglesey_Island',
#  'singh',
#  'javed',
#  'jaffrey',
#  'rajkumar',
#  'hirani',
#  'comedies',
#  'drama',
#  'international',
#  'film',
#  'film',
#  'stripling',
#  'elderly',
#  'Republic_of_India',
#  'attending',
#  '1',
#  'Republic_of_India',
#  'PM',
#  'colleges',
#  '3',
#  'suffering',
#  'engineering',
#  'pupil',
#  'best',
#  'friends',
#  'battle',
#  'round',
#  'schools',
#  'draconian',
#  'system']

# %% [markdown]
# #### 10. Text Normalization

# %% [markdown]
# Text normalization is the process of transforming text data into a standard or canonical form, which makes it easier to process, compare, and analyze. Text normalization is a key step in textual data preprocessing, as it helps to ensure consistency and accuracy in NLP tasks.
#
# Text normalization can involve several techniques, depending on the specific requirements of the task. Some common techniques include:
#
# >* <b>Case normalization:</b> <br>This involves converting all letters to either lowercase or uppercase, to ensure consistency in the text.
#
# >* <b>Lemmatization:</b> <br>This involves reducing words to their base or dictionary form, called a lemma. For example, the lemmas of the words "am," "are," and "is" are all "be." Lemmatization is useful for reducing the dimensionality of the data and improving the accuracy of NLP tasks such as text classification.
#
# >* <b>Stemming:</b> <br>This involves removing the suffixes from words to reduce them to their root form. For example, the stem of the word "running" is "run." Stemming is useful for reducing the dimensionality of the data and improving the accuracy of NLP tasks such as information retrieval.
#
# >* <b>Spell correction:</b> <br>This involves correcting common spelling errors in the text, such as replacing "teh" with "the."
#
# Overall, text normalization is an important step in textual data preprocessing, as it helps to ensure that the text data is consistent, accurate, and in a standard form that can be easily processed and analyzed by machines.

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)
# Function for lemmatization
def lemmatize_text(text):
    lemmatizer = WordNetLemmatizer()
    pos_map = {
        'N': wordnet.NOUN,
        'V': wordnet.VERB,
        'R': wordnet.ADV,
        'J': wordnet.ADJ
    }
    lemmatized_text = []
    for word, tag in nltk.pos_tag(nltk.word_tokenize(text)):
        pos = pos_map.get(tag[0].upper(), wordnet.NOUN)
        lemmatized_word = lemmatizer.lemmatize(word, pos=pos)
        lemmatized_text.append(lemmatized_word)
    return " ".join(lemmatized_text)

# %%
# Applying function for lemmatization to every text using lambda function.
df_new['content_detail']= df_new['content_detail'].apply(lemmatize_text)

# %%
# Checking the observation after manipulation
df_new.iloc[99,]['content_detail']
# Out:
# 'aamir khan kareena kapoor madhavan sharman joshi omi vaidya boman Iranian Anglesey_Island singh javed jaffrey rajkumar hirani comedy drama international film film stripling elderly Republic_of_India attend 1 Republic_of_India PM colleges 3 suffer engineering pupil best friend battle round school draconian system'

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# > We have used Lemmatization Technique for the Normalization of the text. Let's look for the quick differences to know way we use lemmatization.
#
# >* Lemmatization involves reducing words to their base or dictionary form (called a lemma) based on the context of the word in the sentence. This means that words like "ran", "running", and "runs" would all be reduced to the lemma "run". This technique aims to produce a more accurate and meaningful base word for the given context. Lemmatization requires knowledge of the context and part-of-speech (POS) of the word, which makes it more accurate than stemming.
#
# >* Stemming, on the other hand, involves removing the suffixes from words to get their base form (called a stem). This means that words like "running", "runs", and "run" would all be reduced to the stem "run". Stemming is a more aggressive technique compared to lemmatization and may produce stems that are not actual words. Stemming is generally faster than lemmatization, but it may not always produce the most accurate base word for the context.
#
# In summary, lemmatization is more accurate and produces a meaningful base word, while stemming is faster and produces a root form of the word that may not always be a real word. The choice of technique depends on the specific use case and the desired outcome.

# %% [markdown]
# #### 11. Part of speech tagging

# %%
# Let's create the function which take care of requirements
def pos_tagging(tokenized_words):
    '''
    Function takes the rokenized feature as parameter and 
    taged the corresponding word.
    '''
    pos_tags = nltk.pos_tag(tokenized_words)
    return pos_tags

# %%
# POS Taging using lambda funtion
df_new['pos_tags'] = df_new['pos_tags'].apply(pos_tagging)

# %%
# Checking the observation after manipulation
df_new.iloc[99,]['pos_tags'][0:5]
# Out:
# [('aamir', 'RB'),
#  ('khan', 'VB'),
#  ('kareena', 'JJ'),
#  ('kapoor', 'NN'),
#  ('madhavan', 'NN')]

# %% [markdown]
# >* The output you provided is a list of tuples where each tuple contains a tokenized word and its corresponding part-of-speech (POS) tag. The POS tag represents the grammatical category of the word, such as noun (NN), verb (VB), adjective (JJ), and adverb (RB), among others.
#
# >* In your example, the first word "aamir" is tagged as adverb (RB), "khan" as verb (VB), "kareena" as adjective (JJ), "kapoor" and "madhavan" as noun (NN).

# %% [markdown]
# #### 12. Text Vectorization

# %% [markdown]
# Text vectorization is the process of converting textual data into numerical representations, or vectors, that can be processed by machine learning algorithms. This is an important step in natural language processing and text analysis tasks, such as sentiment analysis, document classification, and text generation.
#
# There are various techniques for text vectorization, including:
#
# >* <b>Bag-of-words:</b> <br>This approach represents each document as a set of words and their frequencies. The resulting vector is a sparse representation of the document, where each element corresponds to a word in the vocabulary.
#
# >* <b>TF-IDF:</b> <br>Term frequency-inverse document frequency is a weighted variation of the bag-of-words approach that takes into account the importance of each word in the document and the corpus.
#
# >* <b>Word embeddings:</b> <br>This approach represents each word as a dense vector in a high-dimensional space, where semantically similar words are closer together.

# %%
# Vectorizing Text
# Creating instance
tfidfv = TfidfVectorizer(max_features=30000) # Setting max features as 30000 to avoid RAM explosion

# %%
# Fitting on TfidfVectorizer
x= tfidfv.fit_transform(df_new['content_detail'])

# %%
# Checking shape of the formed document matrix
print(x.shape)
# Out:
# (7770, 30000)

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# >* We use TF-IDF method for the vectorization because of the following reasons.
#
# >* The main difference between these techniques is how they represent the text as vectors. BoW and TF-IDF are based on the frequency of words in the text, while word embeddings are based on the semantic relationships between words.
#
# >* BoW does not consider the order of words in the text, while TF-IDF and word embeddings can capture the context of words.
#
# >* Word embeddings require a large amount of data to train, while BoW and TF-IDF can be computed directly from the text.

# %% [markdown]
# ### 4. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# >* In textual data processing, there are 30,000 arrtibutes are created in text vectorization and this huge amount of columns cannot be dealed with our local machines. So, we will using the Principal Component Analysis(PCA) techniques to reduce the dimensions of this huge sparse matrix.

# %%
# Defining PCA object with desired number of components
pca = PCA()

# %%
# Fitting the PCA model
pca.fit(x.toarray())
# Out:
# PCA()

# %%
# percent of variance captured by each component
variance = pca.explained_variance_ratio_
print(f"Explained variance: {variance}")
# Out:
# Explained variance: [1.18479229e-02 4.38720675e-03 3.59871962e-03 ... 2.48227586e-35
#  1.61233038e-36 1.01010558e-36]

# %%
# Ploting the percent of variance captured versus the number of components in order to determine the reduced dimensions
fig, ax = plt.subplots()
ax.plot(range(1, len(variance)+1), np.cumsum(pca.explained_variance_ratio_))
ax.set_xlabel('Number of Components')
ax.set_ylabel('Percent of Variance Captured')
ax.set_title('PCA Analysis')
plt.grid(linestyle='--', linewidth=0.3, color='#0000')
plt.axhline(y= 0.85, color='red', linestyle='--')
plt.axvline(x= 4000, color='green', linestyle='--')
plt.show()

# %% [markdown]
# >* We find that 100% of the variance is explained by about ~7500 components.
# >* Also, more than 85% of the variance is explained just by 4000 components.
# >* For our case we will consider only those number of PC's that can capture 95% of variance.

# %%
## Now we are passing the argument so that we can capture 95% of variance.
# Defining instance
pca_tuned = PCA(n_components=0.95)

# Fitting and transforming the model
pca_tuned.fit(x.toarray())
x_transformed = pca_tuned.transform(x.toarray())

# Checking the shape of transformed matrix
x_transformed.shape
# Out:
# (7770, 5910)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# >* We have used PCA (Principal Component Analysis) for dimensionality reduction. PCA is a widely used technique for reducing the dimensionality of high-dimensional data sets while retaining most of the information in the original data.
#
# >* PCA works by finding the principal components of the data, which are linear combinations of the original features that capture the maximum amount of variation in the data. By projecting the data onto these principal components, PCA can reduce the number of dimensions while retaining most of the information in the original data.
#
# >* PCA is a popular choice for dimensionality reduction because it is simple to implement, computationally efficient, and widely available in most data analysis software packages. Additionally, PCA has been extensively studied and has a strong theoretical foundation, making it a reliable and well-understood method.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# <hr>
#
# # <center> <font face="Lato" color='E50914'>✴ Conclusion
#
# <hr>

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
